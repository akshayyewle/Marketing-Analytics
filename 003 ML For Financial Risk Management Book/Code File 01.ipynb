# %% [markdown]
# # **Setup**

# %%
# !python3 --version

from psutil import *
print(f'CPU Cores: {cpu_count()}')
print(f'System RAM {virtual_memory()[0]/(1024**3)} GB')
# Out:
# Python 3.11.4
# CPU Cores: 8
# System RAM 8.0 GB

# %%
import os
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
plt.style.use('seaborn')

import plotly 
import statsmodels.api as sm

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # **Basics**

# %% [markdown]
# ## **Generate Random Number**
#
# * Based Standard Normal Distribution

# %%
# Generate A Single Random Numbers
np.random.randn()
# Out:
# -0.16959436568542274

# %%
# Generate An Array Of Random Numbers
np.random.randn(5)
# Out:
# array([-1.90219234, -1.63927041,  0.23936739,  0.48874747,  0.93047312])

# %% [markdown]
# ## **Generate Random Integer**

# %%
# Random Integer Between 0 & 9
np.random.randint(low=0,high=10)
# Out:
# 5

# %%
# Array Of Random Integers Between 0 & 9 
np.random.randint(low=0,high=10,size=(5,5))
# Out:
# array([[3, 4, 7, 3, 8],
#        [9, 5, 0, 3, 7],
#        [9, 6, 6, 4, 6],
#        [1, 7, 4, 8, 6],
#        [6, 5, 6, 0, 2]])

# %% [markdown]
# # **Numpy Number Generator**

# %% [markdown]
# ## **Uniform Random Number**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.uniform.html

# %%
np.random.uniform(low=0,high=10,size=3)
# Out:
# array([0.94746092, 5.74637895, 2.84687431])

# %% [markdown]
# ## **Uniform Random Integers**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.integers.html#numpy.random.Generator.integers

# %%
np.random.random_integers(low=0,high=9,size=3)
# Out:
# array([1, 1, 3])

# %% [markdown]
# ## **Binomial Random Number**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.binomial.html

# %%
np.random.binomial(n=10,p=0.4,size=(3))
# Out:
# array([4, 5, 3])

# %% [markdown]
# ## **Exponential Random Number**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.exponential.html

# %%
np.random.exponential(scale=10,size=3)
# Out:
# array([5.01353298, 4.75675447, 9.80398798])

# %% [markdown]
# ## **Poisson Distribution**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.poisson.html

# %%
np.random.poisson(lam=(1/4),size=3)
# Out:
# array([0, 0, 1])

# %% [markdown]
# ## **Geometric Random Number**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.geometric.html

# %%
np.random.geometric(p=0.35,size=3)
# Out:
# array([3, 2, 1])

# %% [markdown]
# ## **Triangular Random No**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.triangular.html

# %%
np.random.triangular(left=2,mode=5,right=9,size=3   )
# Out:
# array([5.33536198, 5.61430514, 3.82052578])

# %% [markdown]
# # **Probability Distributions**

# %% [markdown]
# ## **Binomial Distribution**

# %%
# A company drills 9 wild-cat oil exploration wells, each with an estimated probability of success of 0.1.
# All nine wells fail. What is the probability of that happening?

# Let's Do 20000 Simulations of this event
sum(np.random.binomial(n=9,p=0.1,size=10000) == 0)/10000
# Out:
# 0.3897

# %%
# Probability Density Function
print('Probability Of 0 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 0)/10000)
print('Probability Of 1 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 1)/10000)
print('Probability Of 2 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 2)/10000)
print('Probability Of 3 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 3)/10000)
print('Probability Of 4 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 4)/10000)
print('Probability Of 5 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 5)/10000)
print('Probability Of 6 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 6)/10000)
print('Probability Of 7 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 7)/10000)
print('Probability Of 8 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 8)/10000)
print('Probability Of 9 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) == 9)/10000)
# Out:
# Probability Of 0 Successful Wells:  0.3848
# Probability Of 1 Successful Wells:  0.3888
# Probability Of 2 Successful Wells:  0.17
# Probability Of 3 Successful Wells:  0.0441
# Probability Of 4 Successful Wells:  0.0075
# Probability Of 5 Successful Wells:  0.0013
# Probability Of 6 Successful Wells:  0.0
# Probability Of 7 Successful Wells:  0.0
# Probability Of 8 Successful Wells:  0.0
# Probability Of 9 Successful Wells:  0.0

# %%
# Cumulative Probability Density Function
print('Probability Of <= 0 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 0)/10000)
print('Probability Of <= 1 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 1)/10000)
print('Probability Of <= 2 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 2)/10000)
print('Probability Of <= 3 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 3)/10000)
print('Probability Of <= 4 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 4)/10000)
print('Probability Of <= 5 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 5)/10000)
print('Probability Of <= 6 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 6)/10000)
print('Probability Of <= 7 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 7)/10000)
print('Probability Of <= 8 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 8)/10000)
print('Probability Of <= 9 Successful Wells: ',sum(np.random.binomial(n=9,p=0.1,size=10000) <= 9)/10000)
# Out:
# Probability Of <= 0 Successful Wells:  0.3879
# Probability Of <= 1 Successful Wells:  0.7652
# Probability Of <= 2 Successful Wells:  0.9485
# Probability Of <= 3 Successful Wells:  0.9916
# Probability Of <= 4 Successful Wells:  0.9993
# Probability Of <= 5 Successful Wells:  0.9999
# Probability Of <= 6 Successful Wells:  1.0
# Probability Of <= 7 Successful Wells:  1.0
# Probability Of <= 8 Successful Wells:  1.0
# Probability Of <= 9 Successful Wells:  1.0

# %% [markdown]
# ## **Exponential Distribution**
#
# * https://numpy.org/doc/stable/reference/random/generated/numpy.random.Generator.exponential.html
# * beta = Scale Parameter = Inter-Event Time Duration
# * Lambda = Rate Parameter = Event Rate = No. Of Events Occuring Per Unit Time

# %%
# Assume a company has 10000 customer support agents and the average time between customer calls is 4 minutes.
# What is the probability that a customer will call in the next 4 to 5 minutes?

array_02 = np.random.exponential(scale=4,size=10000)
array_02
# Out:
# array([5.59622822, 6.18414583, 2.87224642, ..., 1.7996523 , 0.18351209,
#        0.02259777])

# %%
((array >= 0) & (array <=1)).sum()
# Out:
# 2253

# %%
# Cumulative Probability
print(f'Probability Of Call In 0-1 Minute: {(((array >= 0) & (array <=1)).sum())/10000:.4f}')
print(f'Probability Of Call In 1-2 Minute: {(((array >= 1) & (array <=2)).sum())/10000:.4f}')
print(f'Probability Of Call In 2-3 Minute: {(((array >= 2) & (array <=3)).sum())/10000:.4f}')
print(f'Probability Of Call In 3-4 Minute: {(((array >= 3) & (array <=4)).sum())/10000:.4f}')
print(f'Probability Of Call In 4-5 Minute: {(((array >= 4) & (array <=5)).sum())/10000:.4f}')
print(f'Probability Of Call In 5-6 Minute: {(((array >= 5) & (array <=6)).sum())/10000:.4f}')
print(f'Probability Of Call In 6-7 Minute: {(((array >= 6) & (array <=6)).sum())/10000:.4f}')
print(f'Probability Of Call In 7-8 Minute: {(((array >= 7) & (array <=7)).sum())/10000:.4f}')
print(f'Probability Of Call In 8-9 Minute: {(((array >= 8) & (array <=9)).sum())/10000:.4f}')
print(f'Probability Of Call In 9-10 Minute: {(((array >= 8) & (array <=9)).sum())/10000:.4f}')
print(f'Probability Of Call In >10 Minute: {((array >= 10).sum())/10000:.4f}')
# Out:
# Probability Of Call In 0-1 Minute: 0.2253
# Probability Of Call In 1-2 Minute: 0.1744
# Probability Of Call In 2-3 Minute: 0.1400
# Probability Of Call In 3-4 Minute: 0.1023
# Probability Of Call In 4-5 Minute: 0.0826
# Probability Of Call In 5-6 Minute: 0.0573
# Probability Of Call In 6-7 Minute: 0.0000
# Probability Of Call In 7-8 Minute: 0.0000
# Probability Of Call In 8-9 Minute: 0.0292
# Probability Of Call In 9-10 Minute: 0.0292
# Probability Of Call In >10 Minute: 0.0815

# %%
# Cumulative Probability
print(f'Probability Of Call In <= 1 Minute: {((np.random.exponential(scale=4,size=10000) <= 1).sum())/10000:.4f}')
print(f'Probability Of Call In <= 2 Minute: {((np.random.exponential(scale=4,size=10000) <= 2).sum())/10000:.4f}')
print(f'Probability Of Call In <= 3 Minute: {((np.random.exponential(scale=4,size=10000) <= 3).sum())/10000:.4f}')
print(f'Probability Of Call In <= 4 Minute: {((np.random.exponential(scale=4,size=10000) <= 4).sum())/10000:.4f}')
print(f'Probability Of Call In <= 5 Minute: {((np.random.exponential(scale=4,size=10000) <= 5).sum())/10000:.4f}')
print(f'Probability Of Call In <= 6 Minute: {((np.random.exponential(scale=4,size=10000) <= 6).sum())/10000:.4f}')
print(f'Probability Of Call In <= 7 Minute: {((np.random.exponential(scale=4,size=10000) <= 7).sum())/10000:.4f}')
print(f'Probability Of Call In <= 8 Minute: {((np.random.exponential(scale=4,size=10000) <= 8).sum())/10000:.4f}')
print(f'Probability Of Call In <= 9 Minute: {((np.random.exponential(scale=4,size=10000) <= 9).sum())/10000:.4f}')
print(f'Probability Of Call In <= 10 Minute: {((np.random.exponential(scale=4,size=10000) <= 10).sum())/10000:.4f}')
# Out:
# Probability Of Call In <= 1 Minute: 0.2268
# Probability Of Call In <= 2 Minute: 0.3884
# Probability Of Call In <= 3 Minute: 0.5262
# Probability Of Call In <= 4 Minute: 0.6379
# Probability Of Call In <= 5 Minute: 0.7101
# Probability Of Call In <= 6 Minute: 0.7785
# Probability Of Call In <= 7 Minute: 0.8309
# Probability Of Call In <= 8 Minute: 0.8669
# Probability Of Call In <= 9 Minute: 0.8971
# Probability Of Call In <= 10 Minute: 0.9140

# %% [markdown]
# # **01 Consumer Utility Function**
#
# * Assymmetric Risk Management
# * Adverse Selection Model
# * Market For Lemons

# %%
np.exp(1)
# Out:
# 2.718281828459045

# %%
def utility(x):
    return (np.exp(x * gamma))

# %%
pi = np.random.uniform(0,1,20)
pi = np.sort(pi)
pi
# Out:
# array([0.03957733, 0.0959352 , 0.10196046, 0.15833904, 0.22205958,
#        0.27151642, 0.28737194, 0.29484332, 0.31478927, 0.34375212,
#        0.37753303, 0.38726136, 0.57917317, 0.62092504, 0.65758544,
#        0.76504872, 0.79487139, 0.8175866 , 0.97177064, 0.99790504])

# %%
print('3 Highest Probabilities Of Losses: ',pi[-3:])
# Out:
# 3 Highest Probabilities Of Losses:  [0.8175866  0.97177064 0.99790504]

# %%
y = 2   #Income
c = 1.5 #Cost Of Accident
Q = 5
D = 0.01
gamma = 0.4

# %%
def supply(Q):
    return(np.mean(pi[-Q:]) * c)

# %%
def demand(D):
    return(np.sum(utility(y-D) > pi * utility(y-c) + (1-pi) * utility(y)))

# %%
plt.figure()
plt.plot([demand(i) for i in np.arange(0,1.9,0.02)],np.arange(0,1.9,0.02),'r', label='Insurance Demand')
plt.plot(range(1,21),[supply(j) for j in range(1,21)],'g',label='Insurance Supply')
plt.xlabel('No. Of People')
plt.ylabel('Average Cost')
plt.legend()
plt.show()

# %% [markdown]
# # **02 Time Series Modelling**

# %% [markdown]
# ## **Time Series Data**

# %%
import quandl

oil = quandl.get('NSE/OIL',
                #  authtoken=,
                start_date='1980-01-01',end_date='2020-01-01')

print(type(oil))
oil
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                Open     High      Low     Last    Close  Total Trade Quantity  \
# Date
# 2009-09-30  1096.00  1156.70  1090.00  1135.00  1141.20            19748012.0
# 2009-10-01  1102.00  1173.70  1102.00  1167.00  1166.35             3074254.0
# 2009-10-05  1152.00  1165.90  1136.60  1143.00  1140.55              919832.0
# 2009-10-06  1149.80  1157.20  1132.10  1143.30  1144.90              627957.0
# 2009-10-07  1153.80  1160.70  1140.00  1141.45  1141.60              698216.0
# ...             ...      ...      ...      ...      ...                   ...
# 2018-12-31   178.10   179.00   174.35   175.00   174.80              761462.0
# 2019-01-01   175.00   176.40   174.15   175.15   175.75              381570.0
# 2019-01-02   175.80   176.20   171.00   172.35   172.40              722532.0
# 2019-01-03   172.80   175.70   171.50   172.00   172.00              698190.0
# ...

# %%
import yfinance as yf

# %%
NYSE_HDFCBank = yf.Ticker('HDB').history(period='1d',start='2019-01-01',end='2023-01-01')
NYSE_Microsoft = yf.Ticker('MSFT').history(period='1d',start='2019-01-01',end='2023-01-01')

plt.figure(figsize=(10,6))
plt.plot(NYSE_HDFCBank['Close'])
plt.plot(NYSE_Microsoft['Close'])
plt.legend()
plt.ylabel('INR')
plt.xlabel('Date')

plt.axvline(pd.Timestamp('2020-03-15'), color='r', linestyle='--', lw=2)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## **Time Series Components**

# %%
import datetime
import statsmodels.api as sm 
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Out:
# datetime.datetime(2015, 1, 1, 0, 0)

# %%
SP500_Data = yf.download('^GSPC',
                          start=datetime.datetime(2015,1,1),
                          end=datetime.datetime(2021,1,1),
                          interval='1mo')
SP500_Data
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2015-01-01  2058.899902  2072.360107  1988.119995  1994.989990  1994.989990
# 2015-02-01  1996.670044  2119.590088  1980.900024  2104.500000  2104.500000
# 2015-03-01  2105.229980  2117.520020  2039.689941  2067.889893  2067.889893
# 2015-04-01  2067.629883  2125.919922  2048.379883  2085.510010  2085.510010
# 2015-05-01  2087.379883  2134.719971  2067.929932  2107.389893  2107.389893
# ...                 ...          ...          ...          ...          ...
# 2020-08-01  3288.260010  3514.770020  3284.530029  3500.310059  3500.310059
# 2020-09-01  3507.439941  3588.110107  3209.449951  3363.000000  3363.000000
# 2020-10-01  3385.870117  3549.850098  3233.939941  3269.959961  3269.959961
# 2020-11-01  3296.199951  3645.989990  3279.739990  3621.629883  3621.629883
# ...

# %%
seasonal_decompose(SP500_Data['Close'],period=12).plot()
plt.show()

# %% [markdown]
# ## **Plot Trend Line**

# %%
plt.figure(figsize=(8,5))
plt.plot(SP500_Data['Close'])
plt.title('S&P 500 Prices')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.show()

# %% [markdown]
# ## **Auto-Correlation Plot**

# %%
sm.graphics.tsa.plot_acf(SP500_Data['Close'],lags=30)
plt.xlabel('No. Of Lags')
plt.ylabel('Correlation')
plt.show()

# %% [markdown]
# ## **Partial Auto-Correlation**

# %%
sm.graphics.tsa.plot_pacf(SP500_Data['Close'],lags=30)
plt.xlabel('No. Of Lags')
plt.ylabel('Correlation')
plt.show()

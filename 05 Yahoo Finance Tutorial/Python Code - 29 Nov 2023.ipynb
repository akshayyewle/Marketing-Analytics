# %% [markdown]
# # **Setup**
#
# * https://www.youtube.com/watch?v=IF5_BmlvZns

# %%
import yfinance as yf
import yahoo_fin.stock_info as si
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
plt.style.use('ggplot')
import seaborn as sns
from datetime import datetime
from IPython.display import clear_output

from warnings import filterwarnings
filterwarnings('ignore')

# %% [markdown]
# ## **Check Attributes Of Yahoo Finance**

# %%
yf
# Out:
# <module 'yfinance' from 'c:\\Users\\aksha\\AppData\\Local\\Programs\\Python\\Python311\\Lib\\site-packages\\yfinance\\__init__.py'>

# %%
dir(yf)
# Out:
# ['Ticker',
#  'Tickers',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'cache',
#  'const',
#  'data',
#  'download',
#  'enable_debug_mode',
#  'exceptions',
#  'multi',
#  'pdr_override',
#  'scrapers',
#  'set_tz_cache_location',
#  'shared',
#  'ticker',
#  'tickers',
#  'utils',
#  'version']

# %% [markdown]
# # **Get Stock Data**

# %%
# Set Stock Ticker
Apple_Stock_Ticker = 'AAPL'

# %%
# Get Stock Data
Apple_Stock_Data = yf.Ticker(Apple_Stock_Ticker)
Apple_Stock_Data
# Out:
# yfinance.Ticker object <AAPL>

# %%
# Get All Methods & Attributes
print(dir(Apple_Stock_Data))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_analysis', '_base_url', '_data', '_download_options', '_earnings', '_earnings_dates', '_expirations', '_fast_info', '_fetch_ticker_tz', '_financials', '_fix_bad_stock_split', '_fix_missing_div_adjust', '_fix_prices_sudden_change', '_fix_unit_mixups', '_fix_unit_random_mixups', '_fix_unit_switch', '_fix_zeroes', '_fundamentals', '_get_ticker_tz', '_history', '_history_metadata', '_history_metadata_formatted', '_holders', '_isin', '_news', '_options2df', '_quote', '_reconstruct_intervals_batch', '_reconstruct_start_interval', '_shares', '_tz', '_underlying', 'actions', 'analyst_price_target', 'balance_sheet', 'balancesheet', 'basic_info', 'calendar', 'capital_gains', 'cash_flow', 'cashflow', 'dividends', 'earnings', 'earnings_dates', 'earnings_forecasts', 'earnings_trend', 'fast_info', 'financials', 'get_actions', 'get_analyst_price_target', 'get_balance_sheet', 'get_balancesheet', 'get_calendar', 'get_capital_gains', 'get_cash_flow', 'get_cashflow', 'get_dividends', 'get_earnings', 'get_earnings_dates', 'get_earnings_forecast', 'get_earnings_trend', 'get_fast_info', 'get_financials', 'get_history_metadata', 'get_income_stmt', 'get_incomestmt', 'get_info', 'get_institutional_holders', 'get_isin', 'get_major_holders', 'get_mutualfund_holders', 'get_news', 'get_recommendations', 'get_recommendations_summary', 'get_rev_forecast', 'get_shares', 'get_shares_full', 'get_splits', 'get_sustainability', 'get_trend_details', 'history', 'history_metadata', 'income_stmt', 'incomestmt', 'info', 'institutional_holders', 'isin', 'major_holders', 'mutualfund_holders', 'news', 'option_chain', 'options', 'quarterly_balance_sheet', 'quarterly_balancesheet', 'quarterly_cash_flow', 'quarterly_cashflow', 'quarterly_earnings', 'quarterly_financials', 'quarterly_income_stmt', 'quarterly_incomestmt', 'recommendations', 'recommendations_summary', 'revenue_forecasts', 'session', 'shares', 'splits', 'sustainability', 'ticker', 'trend_details']

# %%
# Get Ticker
Apple_Stock_Data.ticker
# Out:
# 'AAPL'

# %% [markdown]
# # **Get Info**

# %%
Apple_Info = Apple_Stock_Data.get_info()
Apple_Info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 161000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 61,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2022,
#    'totalPay': 16425933,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Luca  Maestri',
#    'age': 59,
#    'title': 'CFO & Senior VP',
#    'yearBorn': 1963,
#    'fiscalYear': 2022,
#    'totalPay': 5019783,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 58,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 5018337,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 58,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2022,
#    'totalPay': 5015208,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 55,
#    'title': 'Senior Vice President of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2022,
#    'totalPay': 5019783,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James  Wilson',
#    'title': 'Chief Technology Officer',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Mary  Demby',
#    'title': 'Chief Information Officer',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2022,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 4,
#  'boardRisk': 1,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1701129600,
#  'compensationAsOfEpochDate': 1672444800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 189.79,
#  'open': 189.78,
#  'dayLow': 189.4,
#  'dayHigh': 191.08,
#  'regularMarketPreviousClose': 189.79,
#  'regularMarketOpen': 189.78,
#  'regularMarketDayLow': 189.4,
#  'regularMarketDayHigh': 191.08,
#  'dividendRate': 0.96,
#  'dividendYield': 0.005,
#  'exDividendDate': 1699574400,
#  'payoutRatio': 0.1533,
#  'fiveYearAvgDividendYield': 0.84,
#  'beta': 1.305,
#  'trailingPE': 31.060358,
#  'forwardPE': 26.592178,
#  'volume': 36588319,
#  'regularMarketVolume': 36588319,
#  'averageVolume': 57772142,
#  'averageVolume10days': 44646100,
#  'averageDailyVolume10Day': 44646100,
#  'bid': 190.4,
#  'ask': 190.5,
#  'bidSize': 900,
#  'askSize': 1100,
#  'marketCap': 2961253072896,
#  'fiftyTwoWeekLow': 124.17,
#  'fiftyTwoWeekHigh': 198.23,
#  'priceToSalesTrailing12Months': 7.725982,
#  'fiftyDayAverage': 178.6102,
#  'twoHundredDayAverage': 174.72626,
#  'trailingAnnualDividendRate': 0.94,
#  'trailingAnnualDividendYield': 0.004952843,
#  'currency': 'USD',
#  'enterpriseValue': 3023618965504,
#  'profitMargins': 0.25305998,
#  'floatShares': 15535177390,
#  'sharesOutstanding': 15552799744,
#  'sharesShort': 105837123,
#  'sharesShortPriorMonth': 93026130,
#  'sharesShortPreviousMonthDate': 1697155200,
#  'dateShortInterest': 1700006400,
#  'sharesPercentSharesOut': 0.0068,
#  'heldPercentInsiders': 0.00071999995,
#  'heldPercentInstitutions': 0.61317,
#  'shortRatio': 1.81,
#  'shortPercentOfFloat': 0.0068,
#  'impliedSharesOutstanding': 15552799744,
#  'bookValue': 3.997,
#  'priceToBook': 47.635727,
#  'lastFiscalYearEnd': 1696032000,
#  'nextFiscalYearEnd': 1727654400,
#  'mostRecentQuarter': 1696032000,
#  'earningsQuarterlyGrowth': 0.108,
#  'netIncomeToCommon': 96995000320,
#  'trailingEps': 6.13,
#  'forwardEps': 7.16,
#  'pegRatio': 4.72,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 7.889,
#  'enterpriseToEbitda': 24.031,
#  '52WeekChange': 0.2862258,
#  'SandP52WeekChange': 0.11636448,
#  'lastDividendValue': 0.24,
#  'lastDividendDate': 1699574400,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 190.4,
#  'targetHighPrice': 240.0,
#  'targetLowPrice': 159.0,
#  'targetMeanPrice': 198.01,
#  'targetMedianPrice': 200.0,
#  'recommendationMean': 2.1,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 39,
#  'totalCash': 61554999296,
#  'totalCashPerShare': 3.958,
#  'ebitda': 125820002304,
#  'totalDebt': 123930001408,
#  'quickRatio': 0.843,
#  'currentRatio': 0.988,
#  'totalRevenue': 383285002240,
#  'debtToEquity': 199.418,
#  'revenuePerShare': 24.344,
#  'returnOnAssets': 0.20256001,
#  'returnOnEquity': 1.7195,
#  'grossProfits': 170782000000,
#  'freeCashflow': 82179997696,
#  'operatingCashflow': 110543003648,
#  'earningsGrowth': 0.135,
#  'revenueGrowth': -0.007,
#  'grossMargins': 0.44131002,
#  'ebitdaMargins': 0.32827,
#  'operatingMargins': 0.30134,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.245}

# %% [markdown]
# ## **Company Officers**

# %%
Apple_Info['companyOfficers']
# Out:
# [{'maxAge': 1,
#   'name': 'Mr. Timothy D. Cook',
#   'age': 61,
#   'title': 'CEO & Director',
#   'yearBorn': 1961,
#   'fiscalYear': 2022,
#   'totalPay': 16425933,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. Luca  Maestri',
#   'age': 59,
#   'title': 'CFO & Senior VP',
#   'yearBorn': 1963,
#   'fiscalYear': 2022,
#   'totalPay': 5019783,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. Jeffrey E. Williams',
#   'age': 58,
#   'title': 'Chief Operating Officer',
#   'yearBorn': 1964,
#   'fiscalYear': 2022,
#   'totalPay': 5018337,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Ms. Katherine L. Adams',
#   'age': 58,
#   'title': 'Senior VP, General Counsel & Secretary',
#   'yearBorn': 1964,
#   'fiscalYear': 2022,
#   'totalPay': 5015208,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': "Ms. Deirdre  O'Brien",
#   'age': 55,
#   'title': 'Senior Vice President of Retail',
#   'yearBorn': 1967,
#   'fiscalYear': 2022,
#   'totalPay': 5019783,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. Chris  Kondo',
#   'title': 'Senior Director of Corporate Accounting',
#   'fiscalYear': 2022,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. James  Wilson',
#   'title': 'Chief Technology Officer',
#   'fiscalYear': 2022,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Ms. Mary  Demby',
#   'title': 'Chief Information Officer',
#   'fiscalYear': 2022,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Suhasini  Chandramouli',
#   'title': 'Director of Investor Relations',
#   'fiscalYear': 2022,
#   'exercisedValue': 0,
#   'unexercisedValue': 0},
#  {'maxAge': 1,
#   'name': 'Mr. Greg  Joswiak',
#   'title': 'Senior Vice President of Worldwide Marketing',
#   'fiscalYear': 2022,
#   'exercisedValue': 0,
#   'unexercisedValue': 0}]

# %% [markdown]
# ## **Short Ratio**
#
# is an mathematical indicator of the average number of days a short seller takes to repurchase borrowed securities in the open market.

# %%
Apple_Info['shortRatio']
# Out:
# 1.81

# %% [markdown]
# ## **Beta**
# Expected Movement in the stock relative to the movement in market

# %%
Apple_Info['beta']
# Out:
# 1.305

# %% [markdown]
# ## **PE Ratio**

# %%
Apple_Info['trailingPE']
# Out:
# 31.060358

# %% [markdown]
# ## **Earnings Growth Rate (%)**

# %%
Apple_Info['earningsGrowth']
# Out:
# 0.135

# %% [markdown]
# ## **Business Summary**

# %%
Apple_Info['longBusinessSummary']
# Out:
# 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.'

# %% [markdown]
# # **Get Basic Info**

# %%
Apple_Stock_Data.basic_info.keys()
# Out:
# ['currency',
#  'dayHigh',
#  'dayLow',
#  'exchange',
#  'fiftyDayAverage',
#  'lastPrice',
#  'lastVolume',
#  'marketCap',
#  'open',
#  'previousClose',
#  'quoteType',
#  'regularMarketPreviousClose',
#  'shares',
#  'tenDayAverageVolume',
#  'threeMonthAverageVolume',
#  'timezone',
#  'twoHundredDayAverage',
#  'yearChange',
#  'yearHigh',
#  'yearLow']

# %% [markdown]
# ### **Get Stock Price**

# %%
print('Opening Price: ',Apple_Stock_Data.basic_info['open'])
print('Lastest Price: ',Apple_Stock_Data.basic_info['lastPrice'],'\n')
print('Day High Price: ',Apple_Stock_Data.basic_info['dayHigh'])
print('Day Low Price: ',Apple_Stock_Data.basic_info['dayLow'])
# Out:
# Opening Price:  189.77999877929688
# Lastest Price:  190.39999389648438
#
# Day High Price:  191.0800018310547
# Day Low Price:  189.39999389648438

# %% [markdown]
# ### **Get Market Capitalization**

# %%
print('Market Capitalization: ',round(Apple_Stock_Data.basic_info['marketCap']/(10**9),2),'Billion USD')
# Out:
# Market Capitalization:  2961.25 Billion USD

# %% [markdown]
# ### **Get Trading Currency**

# %%
Apple_Stock_Data.basic_info['currency']
# Out:
# 'USD'

# %% [markdown]
# ### **Get Moving Averages**

# %%
print('50 Day Average: ', Apple_Stock_Data.basic_info['fiftyDayAverage'])
print('200 Day Average: ', Apple_Stock_Data.basic_info['twoHundredDayAverage'])
# Out:
# 50 Day Average:  178.61020080566405
# 200 Day Average:  174.72625045776368

# %% [markdown]
# # **Get Financial Info**

# %% [markdown]
# ## **Get Financial Statement**

# %%
Apple_Stock_Data.get_financials()
# Out:
#                                                         2023-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.147192
# NormalizedEBITDA                                    125820000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   96995000000.0
# ReconciledDepreciation                               11519000000.0
# ReconciledCostOfRevenue                             214137000000.0
# EBITDA                                              125820000000.0
# EBIT                                                114301000000.0
# NetInterestIncome                                              NaN
# InterestExpense                                                NaN
# InterestIncome                                                 NaN
# NormalizedIncome                                     96995000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      96995000000.0
# TotalExpenses                                       268984000000.0
# TotalOperatingIncomeAsReported                      114301000000.0
# DilutedAverageShares                                 15812547000.0
# BasicAverageShares                                   15744231000.0
# DilutedEPS                                                    6.13
# BasicEPS                                                      6.16
# DilutedNIAvailtoComStockholders                      96995000000.0
# NetIncomeCommonStockholders                          96995000000.0
# NetIncome                                            96995000000.0
# NetIncomeIncludingNoncontrollingInterests            96995000000.0
# NetIncomeContinuousOperations                        96995000000.0
# TaxProvision                                         16741000000.0
# PretaxIncome                                        113736000000.0
# OtherIncomeExpense                                    -565000000.0
# OtherNonOperatingIncomeExpenses                       -565000000.0
# NetNonOperatingInterestIncomeExpense                           NaN
# InterestExpenseNonOperating                                    NaN
# InterestIncomeNonOperating                                     NaN
# OperatingIncome                                     114301000000.0
# OperatingExpense                                     54847000000.0
# ResearchAndDevelopment                               29915000000.0
# SellingGeneralAndAdministration                      24932000000.0
# GrossProfit                                         169148000000.0
# CostOfRevenue                                       214137000000.0
# TotalRevenue                                        383285000000.0
# OperatingRevenue                                    383285000000.0
#
#                                                         2022-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.162045
# NormalizedEBITDA                                    130541000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   99803000000.0
# ReconciledDepreciation                               11104000000.0
# ReconciledCostOfRevenue                             223546000000.0
# EBITDA                                              130541000000.0
# EBIT                                                119437000000.0
# NetInterestIncome                                     -106000000.0
# InterestExpense                                       2931000000.0
# InterestIncome                                        2825000000.0
# NormalizedIncome                                     99803000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      99803000000.0
# TotalExpenses                                       274891000000.0
# TotalOperatingIncomeAsReported                      119437000000.0
# DilutedAverageShares                                 16325819000.0
# BasicAverageShares                                   16215963000.0
# DilutedEPS                                                    6.11
# BasicEPS                                                      6.15
# DilutedNIAvailtoComStockholders                      99803000000.0
# NetIncomeCommonStockholders                          99803000000.0
# NetIncome                                            99803000000.0
# NetIncomeIncludingNoncontrollingInterests            99803000000.0
# NetIncomeContinuousOperations                        99803000000.0
# TaxProvision                                         19300000000.0
# PretaxIncome                                        119103000000.0
# OtherIncomeExpense                                    -334000000.0
# OtherNonOperatingIncomeExpenses                       -334000000.0
# NetNonOperatingInterestIncomeExpense                  -106000000.0
# InterestExpenseNonOperating                           2931000000.0
# InterestIncomeNonOperating                            2825000000.0
# OperatingIncome                                     119437000000.0
# OperatingExpense                                     51345000000.0
# ResearchAndDevelopment                               26251000000.0
# SellingGeneralAndAdministration                      25094000000.0
# GrossProfit                                         170782000000.0
# CostOfRevenue                                       223546000000.0
# TotalRevenue                                        394328000000.0
# OperatingRevenue                                    394328000000.0
#
#                                                         2021-09-30  \
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.133023
# NormalizedEBITDA                                    120233000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   94680000000.0
# ReconciledDepreciation                               11284000000.0
# ReconciledCostOfRevenue                             212981000000.0
# EBITDA                                              120233000000.0
# EBIT                                                108949000000.0
# NetInterestIncome                                      198000000.0
# InterestExpense                                       2645000000.0
# InterestIncome                                        2843000000.0
# NormalizedIncome                                     94680000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      94680000000.0
# TotalExpenses                                       256868000000.0
# TotalOperatingIncomeAsReported                      108949000000.0
# DilutedAverageShares                                 16864919000.0
# BasicAverageShares                                   16701272000.0
# DilutedEPS                                                    5.61
# BasicEPS                                                      5.67
# DilutedNIAvailtoComStockholders                      94680000000.0
# NetIncomeCommonStockholders                          94680000000.0
# NetIncome                                            94680000000.0
# NetIncomeIncludingNoncontrollingInterests            94680000000.0
# NetIncomeContinuousOperations                        94680000000.0
# TaxProvision                                         14527000000.0
# PretaxIncome                                        109207000000.0
# OtherIncomeExpense                                     258000000.0
# OtherNonOperatingIncomeExpenses                        258000000.0
# NetNonOperatingInterestIncomeExpense                   198000000.0
# InterestExpenseNonOperating                           2645000000.0
# InterestIncomeNonOperating                            2843000000.0
# OperatingIncome                                     108949000000.0
# OperatingExpense                                     43887000000.0
# ResearchAndDevelopment                               21914000000.0
# SellingGeneralAndAdministration                      21973000000.0
# GrossProfit                                         152836000000.0
# CostOfRevenue                                       212981000000.0
# TotalRevenue                                        365817000000.0
# OperatingRevenue                                    365817000000.0
#
#                                                         2020-09-30
# TaxEffectOfUnusualItems                                        0.0
# TaxRateForCalcs                                           0.144282
# NormalizedEBITDA                                     77344000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   57411000000.0
# ReconciledDepreciation                               11056000000.0
# ReconciledCostOfRevenue                             169559000000.0
# EBITDA                                               77344000000.0
# EBIT                                                 66288000000.0
# NetInterestIncome                                      890000000.0
# InterestExpense                                       2873000000.0
# InterestIncome                                        3763000000.0
# NormalizedIncome                                     57411000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      57411000000.0
# TotalExpenses                                       208227000000.0
# TotalOperatingIncomeAsReported                       66288000000.0
# DilutedAverageShares                                 17528214000.0
# BasicAverageShares                                   17352119000.0
# DilutedEPS                                                    3.28
# BasicEPS                                                      3.31
# DilutedNIAvailtoComStockholders                      57411000000.0
# NetIncomeCommonStockholders                          57411000000.0
# NetIncome                                            57411000000.0
# NetIncomeIncludingNoncontrollingInterests            57411000000.0
# NetIncomeContinuousOperations                        57411000000.0
# TaxProvision                                          9680000000.0
# PretaxIncome                                         67091000000.0
# OtherIncomeExpense                                     803000000.0
# OtherNonOperatingIncomeExpenses                        803000000.0
# NetNonOperatingInterestIncomeExpense                   890000000.0
# InterestExpenseNonOperating                           2873000000.0
# InterestIncomeNonOperating                            3763000000.0
# OperatingIncome                                      66288000000.0
# OperatingExpense                                     38668000000.0
# ResearchAndDevelopment                               18752000000.0
# SellingGeneralAndAdministration                      19916000000.0
# GrossProfit                                         104956000000.0
# CostOfRevenue                                       169559000000.0
# TotalRevenue                                        274515000000.0
# OperatingRevenue                                    274515000000.0

# %%
type(Apple_Stock_Data.get_financials())
# Out:
# pandas.core.frame.DataFrame

# %%
Apple_Stock_Data.get_financials().index
# Out:
# Index(['TaxEffectOfUnusualItems', 'TaxRateForCalcs', 'NormalizedEBITDA',
#        'NetIncomeFromContinuingOperationNetMinorityInterest',
#        'ReconciledDepreciation', 'ReconciledCostOfRevenue', 'EBITDA', 'EBIT',
#        'NetInterestIncome', 'InterestExpense', 'InterestIncome',
#        'NormalizedIncome', 'NetIncomeFromContinuingAndDiscontinuedOperation',
#        'TotalExpenses', 'TotalOperatingIncomeAsReported',
#        'DilutedAverageShares', 'BasicAverageShares', 'DilutedEPS', 'BasicEPS',
#        'DilutedNIAvailtoComStockholders', 'NetIncomeCommonStockholders',
#        'NetIncome', 'NetIncomeIncludingNoncontrollingInterests',
#        'NetIncomeContinuousOperations', 'TaxProvision', 'PretaxIncome',
#        'OtherIncomeExpense', 'OtherNonOperatingIncomeExpenses',
#        'NetNonOperatingInterestIncomeExpense', 'InterestExpenseNonOperating',
#        'InterestIncomeNonOperating', 'OperatingIncome', 'OperatingExpense',
#        'ResearchAndDevelopment', 'SellingGeneralAndAdministration',
#        'GrossProfit', 'CostOfRevenue', 'TotalRevenue', 'OperatingRevenue'],
#       dtype='object')

# %% [markdown]
# ### **Plot EBITDA**

# %%
Apple_Stock_Data.get_financials().loc['EBITDA']
# Out:
# 2023-09-30    125820000000.0
# 2022-09-30    130541000000.0
# 2021-09-30    120233000000.0
# 2020-09-30     77344000000.0
# Name: EBITDA, dtype: object

# %%
Apple_Stock_Data.get_financials().loc['EBITDA'].index
# Out:
# DatetimeIndex(['2023-09-30', '2022-09-30', '2021-09-30', '2020-09-30'], dtype='datetime64[ns]', freq=None)

# %%
Apple_Stock_Data.get_financials().loc['EBITDA'].values
# Out:
# array([125820000000.0, 130541000000.0, 120233000000.0, 77344000000.0],
#       dtype=object)

# %%
plt.plot(
    Apple_Stock_Data.get_financials().loc['EBITDA'].index,
    Apple_Stock_Data.get_financials().loc['EBITDA'].values,
    marker='o')
plt.xticks(rotation=45)
plt.title('Apple EBITDA')
# Out:
# Text(0.5, 1.0, 'Apple EBITDA')

# %% [markdown]
# ## **Get Revenue**

# %%
Apple_Revenue = Apple_Stock_Data.get_financials().loc['CostOfRevenue':"OperatingRevenue"]
Apple_Revenue
# Out:
#                       2023-09-30      2022-09-30      2021-09-30  \
# CostOfRevenue     214137000000.0  223546000000.0  212981000000.0
# TotalRevenue      383285000000.0  394328000000.0  365817000000.0
# OperatingRevenue  383285000000.0  394328000000.0  365817000000.0
#
#                       2020-09-30
# CostOfRevenue     169559000000.0
# TotalRevenue      274515000000.0
# OperatingRevenue  274515000000.0

# %%
# Transpose The Data
Apple_Revenue = Apple_Revenue.T

# Conver Values To Billions
Apple_Revenue = Apple_Revenue/(10**9)
Apple_Revenue
# Out:
#            CostOfRevenue TotalRevenue OperatingRevenue
# 2023-09-30       214.137      383.285          383.285
# 2022-09-30       223.546      394.328          394.328
# 2021-09-30       212.981      365.817          365.817
# 2020-09-30       169.559      274.515          274.515

# %% [markdown]
# ### **Plot Revenue**

# %%
fig,axs = plt.subplots(1,2,layout='constrained')
sns.barplot(Apple_Revenue,x=Apple_Revenue.index,y='CostOfRevenue',ax=axs[0])
sns.barplot(Apple_Revenue,x=Apple_Revenue.index,y='TotalRevenue',ax=axs[1])
ax.set_ylabel('Revenue in Billion USD')
ax.set_title('Apple Stock Revenue Analysis')
# Out:
# Text(0.5, 1.0, 'Apple Stock Revenue Analysis')

# %% [markdown]
# # **Get Shareholder Details**

# %% [markdown]
# ## **Major Shareholders**

# %%
Apple_Stock_Data.get_major_holders()
# Out:
#         0                                      1
# 0   0.07%        % of Shares Held by All Insider
# 1  61.32%       % of Shares Held by Institutions
# 2  61.36%        % of Float Held by Institutions
# 3    5762  Number of Institutions Holding Shares

# %% [markdown]
# ## **Institutional Holders**

# %%
Apple_Stock_Data.get_institutional_holders()
# Out:
#                               Holder      Shares Date Reported   % Out  \
# 0                 Vanguard Group Inc  1299997133    2023-09-29  0.0836
# 1                     Blackrock Inc.  1031407553    2023-09-29  0.0663
# 2            Berkshire Hathaway, Inc   915560382    2023-09-29  0.0589
# 3           State Street Corporation   569291690    2023-09-29  0.0366
# 4                           FMR, LLC   298321726    2023-09-29  0.0192
# 5      Geode Capital Management, LLC   296103070    2023-09-29  0.0190
# 6      Price (T.Rowe) Associates Inc   216307878    2023-09-29  0.0139
# 7                     Morgan Stanley   206732960    2023-09-29  0.0133
# 8         Northern Trust Corporation   168874976    2023-09-29  0.0109
# 9  Norges Bank Investment Management   167374278    2022-12-30  0.0108
#
#           Value
# 0  247519446188
# 1  196379991795
# 2  174322691144
# 3  108393134301
# 4   56800454809
# 5   56378022720
# 6   41185018650
# 7   39361954322
# 8   32153794399
# 9   31868061509

# %% [markdown]
# ## **Mutual Fund Holders**

# %%
Apple_Stock_Data.get_mutualfund_holders()
# Out:
#                                               Holder     Shares Date Reported  \
# 0             Vanguard Total Stock Market Index Fund  465990265    2023-06-29
# 1                            Vanguard 500 Index Fund  352024182    2023-06-29
# 2                            Fidelity 500 Index Fund  169378703    2023-08-30
# 3                             SPDR S&P 500 ETF Trust  165192563    2023-09-29
# 4                           iShares Core S&P 500 ETF  138678373    2023-09-29
# 5                         Vanguard Growth Index Fund  127130805    2023-06-29
# 6        Invesco ETF Tr-Invesco QQQ Tr, Series 1 ETF  124636013    2023-09-29
# 7  Vanguard Institutional Index Fund-Institutiona...   98610773    2023-09-29
# 8         Vanguard Information Technology Index Fund   76972129    2023-08-30
# 9                 Select Sector SPDR Fund-Technology   64668259    2023-09-29
#
#     % Out        Value
# 0  0.0300  88724543611
# 1  0.0226  67025402104
# 2  0.0109  32249704017
# 3  0.0106  31452662986
# 4  0.0089  26404361372
# 5  0.0082  24205704496
# 6  0.0080  23730696114
# 7  0.0063  18775490577
# 8  0.0049  14655492891
# 9  0.0042  12312836118

# %% [markdown]
# # **Options Data**

# %%
# Options Data
Apple_Stock_Data.option_chain()
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL231201C00050000 2023-11-28 17:19:29+00:00    50.0     141.70  140.10
# 1   AAPL231201C00075000 2023-10-31 18:17:13+00:00    75.0      95.40  115.15
# 2   AAPL231201C00085000 2023-11-21 16:41:12+00:00    85.0     105.03  105.10
# 3   AAPL231201C00090000 2023-11-21 16:41:12+00:00    90.0     100.02  100.15
# 4   AAPL231201C00100000 2023-11-24 17:43:25+00:00   100.0      89.65   90.15
# 5   AAPL231201C00125000 2023-11-24 17:43:57+00:00   125.0      64.84   65.15
# 6   AAPL231201C00130000 2023-11-27 17:14:39+00:00   130.0      60.46   60.25
# 7   AAPL231201C00135000 2023-11-24 16:53:42+00:00   135.0      54.73   55.20
# 8   AAPL231201C00140000 2023-11-27 15:58:10+00:00   140.0      52.10   50.20
# 9   AAPL231201C00145000 2023-11-28 19:28:24+00:00   145.0      44.92   45.20
# 10  AAPL231201C00150000 2023-11-29 16:01:34+00:00   150.0      40.96   40.20
# 11  AAPL231201C00155000 2023-11-27 19:01:00+00:00   155.0      35.27   35.10
# 12  AAPL231201C00160000 2023-11-29 15:31:45+00:00   160.0      31.00   30.25
# 13  AAPL231201C00162500 2023-11-24 14:47:14+00:00   162.5      27.66   27.75
# 14  AAPL231201C00165000 2023-11-29 15:48:10+00:00   165.0      25.85   25.15
# 15  AAPL231201C00167500 2023-11-28 20:50:00+00:00   167.5      22.75   22.75
# 16  AAPL231201C00170000 2023-11-29 15:17:22+00:00   170.0      21.00   20.30
# 17  AAPL231201C00172500 2023-11-29 14:30:04+00:00   172.5      18.90   17.70
# 18  AAPL231201C00175000 2023-11-29 16:04:09+00:00   175.0      16.01   15.25
# 19  AAPL231201C00177500 2023-11-29 16:13:33+00:00   177.5      13.11   12.65
# 20  AAPL231201C00180000 2023-11-29 16:17:57+00:00   180.0      10.37   10.30
# 21  AAPL231201C00182500 2023-11-29 16:20:10+00:00   182.5       7.90    7.80
# 22  AAPL231201C00185000 2023-11-29 16:18:26+00:00   185.0       5.40    5.40
# 23  AAPL231201C00187500 2023-11-29 16:19:53+00:00   187.5       3.10    3.00
# 24  AAPL231201C00190000 2023-11-29 16:21:37+00:00   190.0       1.25    1.21
# 25  AAPL231201C00192500 2023-11-29 16:21:43+00:00   192.5       0.30    0.28
# 26  AAPL231201C00195000 2023-11-29 16:21:52+00:00   195.0       0.06    0.05
# 27  AAPL231201C00197500 2023-11-29 16:17:18+00:00   197.5       0.01    0.01
# 28  AAPL231201C00200000 2023-11-29 16:21:33+00:00   200.0       0.01    0.00
# 29  AAPL231201C00202500 2023-11-29 15:08:09+00:00   202.5       0.01    0.00
# 30  AAPL231201C00205000 2023-11-28 20:44:10+00:00   205.0       0.01    0.00
# 31  AAPL231201C00207500 2023-11-28 17:25:33+00:00   207.5       0.01    0.00
# 32  AAPL231201C00210000 2023-11-28 14:46:31+00:00   210.0       0.01    0.00
# 33  AAPL231201C00212500 2023-11-22 16:48:28+00:00   212.5       0.01    0.00
# 34  AAPL231201C00215000 2023-11-24 17:24:08+00:00   215.0       0.01    0.00
# 35  AAPL231201C00220000 2023-11-20 14:35:32+00:00   220.0       0.01    0.00
# 36  AAPL231201C00225000 2023-11-20 15:54:42+00:00   225.0       0.01    0.00
# 37  AAPL231201C00230000 2023-11-24 17:24:08+00:00   230.0       0.01    0.00
# 38  AAPL231201C00235000 2023-11-02 19:47:00+00:00   235.0       0.02    0.00
# 39  AAPL231201C00240000 2023-11-27 14:30:17+00:00   240.0       0.01    0.00
# 40  AAPL231201C00245000 2023-11-29 14:30:00+00:00   245.0       0.01    0.00
# 41  AAPL231201C00265000 2023-11-28 17:47:41+00:00   265.0       0.01    0.00
#
#        ask    change  percentChange   volume  openInterest  impliedVolatility  \
# 0   140.30  1.050003       0.746536      1.0             9           5.609378
# 1   115.45  0.000000       0.000000      NaN             0           3.968750
# 2   105.40  0.000000       0.000000      1.0             4           3.000002
# 3   100.40  0.000000       0.000000      NaN             1           3.078127
# 4    90.45  0.000000       0.000000      7.0             8           2.812503
# 5    65.40  0.000000       0.000000      2.0            10           1.796876
# 6    60.45  0.000000       0.000000      1.0            77           1.871094
# 7    55.50  0.000000       0.000000     25.0            43           1.707033
# 8    50.55  2.570000       5.188774      1.0            48           1.589846
# 9    45.40  0.000000       0.000000      9.0            61           1.285160
# 10   40.40  0.459999       1.135800      3.0            62           1.140629
# 11   35.40  0.000000       0.000000      5.0           103           0.843752
# 12   30.40  0.600000       1.973685     20.0           596           0.904298
# 13   27.95  0.000000       0.000000      1.0            38           0.865236
# 14   25.45  0.900000       3.607213     16.0           519           0.728518
# 15   23.05  0.000000       0.000000     27.0            37           0.767580
# 16   20.45  0.500000       2.439024    125.0           829           0.671878
# 17   17.90  0.990000       5.527637      5.0           122           0.527348
# 18   15.50  0.800000       5.259698     37.0          2562           0.525395
# 19   12.95  0.660000       5.301204     23.0           639           0.493169
# 20   10.45 -0.130000      -1.238096    155.0          6440           0.413092
# 21    7.95 -0.150000      -1.863355     97.0          1212           0.332038
# 22    5.55 -0.120000      -2.173911   5643.0         17536           0.276374
# 23    3.05 -0.100000      -3.125005   1161.0          6814           0.179696
# 24    1.23 -0.140000     -10.071941  16539.0         25417           0.161141
# 25    0.29 -0.070000     -18.918917  35481.0         31675           0.152841
# 26    0.06 -0.010000     -14.285716  11895.0         28164           0.166024
# 27    0.02  0.000000       0.000000   2624.0         21797           0.193367
# 28    0.01  0.000000       0.000000   1398.0         17927           0.226570
# 29    0.00  0.000000       0.000000      6.0          2559           0.125009
# 30    0.00  0.000000       0.000000      6.0          1629           0.250007
# 31    0.01  0.000000       0.000000      2.0           255           0.367194
# 32    0.01  0.000000       0.000000      2.0           833           0.414068
# 33    0.01  0.000000       0.000000      1.0           277           0.460943
# 34    0.01  0.000000       0.000000      1.0            85           0.500005
# 35    0.01  0.000000       0.000000     36.0           201           0.546880
# 36    0.01  0.000000       0.000000      5.0            49           0.625004
# 37    0.01  0.000000       0.000000      1.0             2           0.687503
# 38    0.01  0.000000       0.000000    102.0           104           0.765627
# 39    0.01  0.000000       0.000000      1.0           201           0.843752
# 40    0.01  0.000000       0.000000      1.0             2           0.906251
# 41    0.01  0.000000       0.000000      2.0             7           1.156254
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9         True      REGULAR      USD
# 10        True      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD
# 40       False      REGULAR      USD
# 41       False      REGULAR      USD  , puts=         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL231201P00050000 2023-11-29 14:30:00+00:00    50.0       0.01   0.00
# 1   AAPL231201P00075000 2023-10-18 15:00:55+00:00    75.0       0.01   0.00
# 2   AAPL231201P00090000 2023-11-03 19:53:21+00:00    90.0       0.01   0.00
# 3   AAPL231201P00095000 2023-11-03 19:57:42+00:00    95.0       0.01   0.00
# 4   AAPL231201P00100000 2023-11-17 20:43:44+00:00   100.0       0.01   0.00
# 5   AAPL231201P00105000 2023-11-22 19:59:42+00:00   105.0       0.01   0.00
# 6   AAPL231201P00110000 2023-11-17 16:09:12+00:00   110.0       0.01   0.00
# 7   AAPL231201P00115000 2023-11-22 20:09:25+00:00   115.0       0.01   0.00
# 8   AAPL231201P00120000 2023-11-21 20:44:48+00:00   120.0       0.01   0.00
# 9   AAPL231201P00125000 2023-11-24 17:59:54+00:00   125.0       0.01   0.00
# 10  AAPL231201P00130000 2023-11-27 15:35:38+00:00   130.0       0.01   0.00
# 11  AAPL231201P00135000 2023-11-24 16:43:02+00:00   135.0       0.01   0.00
# 12  AAPL231201P00140000 2023-11-27 14:35:17+00:00   140.0       0.01   0.00
# 13  AAPL231201P00145000 2023-11-28 15:05:33+00:00   145.0       0.01   0.00
# 14  AAPL231201P00149000 2023-11-27 14:34:17+00:00   149.0       0.01   0.00
# 15  AAPL231201P00150000 2023-11-28 20:52:24+00:00   150.0       0.01   0.00
# 16  AAPL231201P00155000 2023-11-29 16:10:47+00:00   155.0       0.01   0.00
# 17  AAPL231201P00157500 2023-11-27 20:56:12+00:00   157.5       0.01   0.00
# 18  AAPL231201P00160000 2023-11-29 14:40:04+00:00   160.0       0.01   0.00
# 19  AAPL231201P00162500 2023-11-28 16:35:11+00:00   162.5       0.01   0.00
# 20  AAPL231201P00165000 2023-11-29 16:16:35+00:00   165.0       0.01   0.00
# 21  AAPL231201P00167500 2023-11-29 15:14:24+00:00   167.5       0.01   0.00
# 22  AAPL231201P00170000 2023-11-29 16:15:26+00:00   170.0       0.01   0.00
# 23  AAPL231201P00172500 2023-11-29 15:53:12+00:00   172.5       0.01   0.00
# 24  AAPL231201P00175000 2023-11-29 16:16:02+00:00   175.0       0.01   0.01
# 25  AAPL231201P00177500 2023-11-29 15:46:32+00:00   177.5       0.02   0.01
# 26  AAPL231201P00180000 2023-11-29 16:14:21+00:00   180.0       0.03   0.02
# 27  AAPL231201P00182500 2023-11-29 16:21:05+00:00   182.5       0.04   0.03
# 28  AAPL231201P00185000 2023-11-29 16:20:20+00:00   185.0       0.07   0.06
# 29  AAPL231201P00187500 2023-11-29 16:21:44+00:00   187.5       0.21   0.22
# 30  AAPL231201P00190000 2023-11-29 16:21:43+00:00   190.0       0.84   0.83
# 31  AAPL231201P00192500 2023-11-29 16:20:58+00:00   192.5       2.46   2.47
# 32  AAPL231201P00195000 2023-11-29 16:17:33+00:00   195.0       4.70   4.75
# 33  AAPL231201P00197500 2023-11-29 16:18:30+00:00   197.5       7.30   7.25
# 34  AAPL231201P00200000 2023-11-29 16:10:47+00:00   200.0       9.37   9.70
# 35  AAPL231201P00202500 2023-11-27 14:48:01+00:00   202.5      13.43  12.10
# 36  AAPL231201P00205000 2023-11-29 15:34:13+00:00   205.0      14.00  14.70
# 37  AAPL231201P00210000 2023-11-29 16:18:56+00:00   210.0      19.75  19.65
# 38  AAPL231201P00215000 2023-11-28 16:06:09+00:00   215.0      24.50  24.70
# 39  AAPL231201P00225000 2023-11-21 16:03:06+00:00   225.0      34.80  34.70
# 40  AAPL231201P00230000 2023-11-28 17:36:10+00:00   230.0      39.55  39.65
# 41  AAPL231201P00240000 2023-11-15 14:34:26+00:00   240.0      51.40  49.70
# 42  AAPL231201P00250000 2023-10-20 13:49:58+00:00   250.0      74.65  60.15
# 43  AAPL231201P00265000 2023-11-27 14:55:37+00:00   265.0      75.80  74.65
#
#       ask  change  percentChange   volume  openInterest  impliedVolatility  \
# 0    0.01    0.00       0.000000     21.0             4           4.500004
# 1    0.01    0.00       0.000000      NaN            25           3.125002
# 2    0.01    0.00       0.000000      1.0           103           2.562504
# 3    0.01    0.00       0.000000     24.0            86           2.375004
# 4    0.01    0.00       0.000000     10.0           174           2.187505
# 5    0.00    0.00       0.000000    348.0           401           0.500005
# 6    0.01    0.00       0.000000    200.0           258           1.875001
# 7    0.01    0.00       0.000000    200.0           534           1.750001
# 8    0.01    0.00       0.000000      2.0           157           1.625002
# 9    0.01    0.00       0.000000   7005.0         13710           1.500002
# 10   0.01    0.00       0.000000      3.0          9887           1.343753
# 11   0.01    0.00       0.000000    586.0          1190           1.218754
# 12   0.01    0.00       0.000000      5.0          1742           1.093755
# 13   0.01    0.00       0.000000      5.0          1341           0.968750
# 14   0.01    0.00       0.000000    499.0          1536           0.906251
# 15   0.01    0.00       0.000000      1.0          2774           0.875001
# 16   0.01    0.00       0.000000      1.0          5313           0.750003
# 17   0.01    0.00       0.000000    650.0          1137           0.703128
# 18   0.01    0.00       0.000000      9.0         13056           0.656253
# 19   0.01    0.00       0.000000     82.0           767           0.593754
# 20   0.01    0.00       0.000000     54.0          4421           0.546880
# 21   0.00    0.00       0.000000      8.0          2615           0.250007
# 22   0.01   -0.01     -50.000000    630.0          8880           0.468755
# 23   0.01    0.00       0.000000    330.0          7907           0.414068
# 24   0.02   -0.01     -50.000000     63.0         13462           0.390631
# 25   0.02   -0.02     -50.000000     58.0          5448           0.332038
# 26   0.03   -0.01     -25.000000    477.0         17433           0.289070
# 27   0.04   -0.02     -33.333336    578.0          6520           0.236336
# 28   0.07   -0.03     -30.000002   4054.0         53247           0.189461
# 29   0.23   -0.06     -22.222229  11302.0         21008           0.160165
# 30   0.84   -0.09      -9.677423  29105.0         15776           0.138680
# 31   2.50    0.00       0.000000  10189.0         10997           0.141122
# 32   4.85   -0.05      -1.052636    606.0           591           0.178719
# 33   7.35   -0.01      -0.136796     33.0           166           0.247078
# 34   9.85   -0.47      -4.776425      6.0            18           0.312507
# 35  12.30    0.00       0.000000      1.0             2           0.324226
# 36  14.85   -1.15      -7.590757     60.0             0           0.433599
# 37  19.85   -0.10      -0.503780     10.0             0           0.546880
# 38  24.85    0.00       0.000000      3.0             2           0.500005
# 39  34.95    0.00       0.000000      NaN             0           0.812502
# 40  39.90    0.00       0.000000      2.0             1           0.750003
# 41  49.95    0.00       0.000000      NaN             0           1.078130
# 42  60.45    0.00       0.000000     10.0             0           1.713869
# 43  74.80    0.00       0.000000      2.0             0           1.382816
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31        True      REGULAR      USD
# 32        True      REGULAR      USD
# 33        True      REGULAR      USD
# 34        True      REGULAR      USD
# 35        True      REGULAR      USD
# 36        True      REGULAR      USD
# 37        True      REGULAR      USD
# 38        True      REGULAR      USD
# 39        True      REGULAR      USD
# 40        True      REGULAR      USD
# 41        True      REGULAR      USD
# 42        True      REGULAR      USD
# 43        True      REGULAR      USD  , underlying={'language': 'en-US', 'region': 'US', 'quoteType': 'EQUITY', 'typeDisp': 'Equity', 'quoteSourceName': 'Nasdaq Real Time Price', 'triggerable': True, 'customPriceAlertConfidence': 'HIGH', 'currency': 'USD', 'marketState': 'REGULAR', 'regularMarketChangePercent': -0.08665614, 'regularMarketPrice': 190.235, 'exchange': 'NMS', 'shortName': 'Apple Inc.', 'longName': 'Apple Inc.', 'messageBoardId': 'finmb_24937', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EST', 'gmtOffSetMilliseconds': -18000000, 'market': 'us_market', 'esgPopulated': False, 'firstTradeDateMilliseconds': 345479400000, 'priceHint': 2, 'regularMarketChange': -0.16499329, 'regularMarketTime': 1701275822, 'regularMarketDayHigh': 192.09, 'regularMarketDayRange': '189.9103 - 192.09', 'regularMarketDayLow': 189.9103, 'regularMarketVolume': 14755273, 'regularMarketPreviousClose': 190.4, 'bid': 190.31, 'ask': 190.3, 'bidSize': 8, 'askSize': 8, 'fullExchangeName': 'NasdaqGS', 'financialCurrency': 'USD', 'regularMarketOpen': 189.78, 'averageDailyVolume3Month': 57772142, 'averageDailyVolume10Day': 44646100, 'fiftyTwoWeekLowChange': 66.065, 'fiftyTwoWeekLowChangePercent': 0.5320529, 'fiftyTwoWeekRange': '124.17 - 198.23', 'fiftyTwoWeekHighChange': -7.994995, 'fiftyTwoWeekHighChangePercent': -0.040331915, 'fiftyTwoWeekLow': 124.17, 'fiftyTwoWeekHigh': 198.23, 'fiftyTwoWeekChangePercent': 28.62258, 'dividendDate': 1700092800, 'earningsTimestamp': 1698958800, 'earningsTimestampStart': 1706698740, 'earningsTimestampEnd': 1707134400, 'trailingAnnualDividendRate': 0.94, 'trailingPE': 31.033442, 'dividendRate': 0.96, 'trailingAnnualDividendYield': 0.004936975, 'dividendYield': 0.5, 'epsTrailingTwelveMonths': 6.13, 'epsForward': 7.16, 'epsCurrentYear': 6.57, 'priceEpsCurrentYear': 28.9551, 'sharesOutstanding': 15552799744, 'bookValue': 3.997, 'fiftyDayAverage': 178.6102, 'fiftyDayAverageChange': 11.624802, 'fiftyDayAverageChangePercent': 0.065084755, 'twoHundredDayAverage': 174.72626, 'twoHundredDayAverageChange': 15.508743, 'twoHundredDayAverageChangePercent': 0.088760234, 'marketCap': 2958686945280, 'forwardPE': 26.569136, 'priceToBook': 47.594448, 'sourceInterval': 15, 'exchangeDataDelayedBy': 0, 'averageAnalystRating': '2.1 - Buy', 'tradeable': False, 'cryptoTradeable': False, 'displayName': 'Apple', 'symbol': 'AAPL'})

# %%
len(Apple_Stock_Data.option_chain())
# Out:
# 3

# %% [markdown]
# ## **Call Options**

# %%
# Call Options Dataframe
Apple_Call_Options = Apple_Stock_Data.option_chain()[0]
Apple_Call_Options
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0   AAPL231201C00050000 2023-11-28 17:19:29+00:00    50.0     141.70  140.05
# 1   AAPL231201C00075000 2023-10-31 18:17:13+00:00    75.0      95.40  114.95
# 2   AAPL231201C00085000 2023-11-21 16:41:12+00:00    85.0     105.03  105.00
# 3   AAPL231201C00090000 2023-11-21 16:41:12+00:00    90.0     100.02  100.20
# 4   AAPL231201C00100000 2023-11-24 17:43:25+00:00   100.0      89.65   90.05
# 5   AAPL231201C00125000 2023-11-24 17:43:57+00:00   125.0      64.84   65.05
# 6   AAPL231201C00130000 2023-11-27 17:14:39+00:00   130.0      60.46   60.00
# 7   AAPL231201C00135000 2023-11-24 16:53:42+00:00   135.0      54.73   55.10
# 8   AAPL231201C00140000 2023-11-27 15:58:10+00:00   140.0      52.10   50.00
# 9   AAPL231201C00145000 2023-11-28 19:28:24+00:00   145.0      44.92   45.00
# 10  AAPL231201C00150000 2023-11-29 16:01:34+00:00   150.0      40.96   40.15
# 11  AAPL231201C00155000 2023-11-27 19:01:00+00:00   155.0      35.27   35.05
# 12  AAPL231201C00160000 2023-11-29 15:31:45+00:00   160.0      31.00   30.10
# 13  AAPL231201C00162500 2023-11-24 14:47:14+00:00   162.5      27.66   27.55
# 14  AAPL231201C00165000 2023-11-29 15:48:10+00:00   165.0      25.85   25.10
# 15  AAPL231201C00167500 2023-11-28 20:50:00+00:00   167.5      22.75   22.55
# 16  AAPL231201C00170000 2023-11-29 16:27:38+00:00   170.0      20.27   20.10
# 17  AAPL231201C00172500 2023-11-29 14:30:04+00:00   172.5      18.90   17.60
# 18  AAPL231201C00175000 2023-11-29 16:04:09+00:00   175.0      15.37   15.15
# 19  AAPL231201C00177500 2023-11-29 16:13:33+00:00   177.5      13.11   12.60
# 20  AAPL231201C00180000 2023-11-29 16:28:06+00:00   180.0      10.22   10.15
# 21  AAPL231201C00182500 2023-11-29 16:29:43+00:00   182.5       7.70    7.65
# 22  AAPL231201C00185000 2023-11-29 16:30:15+00:00   185.0       5.25    5.20
# 23  AAPL231201C00187500 2023-11-29 16:27:02+00:00   187.5       3.00    2.90
# 24  AAPL231201C00190000 2023-11-29 16:30:14+00:00   190.0       1.12    1.12
# 25  AAPL231201C00192500 2023-11-29 16:30:07+00:00   192.5       0.26    0.25
# 26  AAPL231201C00195000 2023-11-29 16:29:36+00:00   195.0       0.06    0.05
# 27  AAPL231201C00197500 2023-11-29 16:23:11+00:00   197.5       0.02    0.01
# 28  AAPL231201C00200000 2023-11-29 16:21:33+00:00   200.0       0.01    0.00
# 29  AAPL231201C00202500 2023-11-29 15:08:09+00:00   202.5       0.01    0.00
# 30  AAPL231201C00205000 2023-11-28 20:44:10+00:00   205.0       0.01    0.00
# 31  AAPL231201C00207500 2023-11-28 17:25:33+00:00   207.5       0.01    0.00
# 32  AAPL231201C00210000 2023-11-28 14:46:31+00:00   210.0       0.01    0.00
# 33  AAPL231201C00212500 2023-11-22 16:48:28+00:00   212.5       0.01    0.00
# 34  AAPL231201C00215000 2023-11-24 17:24:08+00:00   215.0       0.01    0.00
# 35  AAPL231201C00220000 2023-11-20 14:35:32+00:00   220.0       0.01    0.00
# 36  AAPL231201C00225000 2023-11-20 15:54:42+00:00   225.0       0.01    0.00
# 37  AAPL231201C00230000 2023-11-24 17:24:08+00:00   230.0       0.01    0.00
# 38  AAPL231201C00235000 2023-11-02 19:47:00+00:00   235.0       0.02    0.00
# 39  AAPL231201C00240000 2023-11-27 14:30:17+00:00   240.0       0.01    0.00
# 40  AAPL231201C00245000 2023-11-29 14:30:00+00:00   245.0       0.01    0.00
# 41  AAPL231201C00265000 2023-11-28 17:47:41+00:00   265.0       0.01    0.00
#
#        ask    change  percentChange   volume  openInterest  impliedVolatility  \
# 0   140.20  1.050003       0.746536      1.0             9           5.031254
# 1   115.25  0.000000       0.000000      NaN             0           4.367192
# 2   105.25  0.000000       0.000000      1.0             4           3.093752
# 3   100.45  0.000000       0.000000      NaN             1           3.765626
# 4    90.30  0.000000       0.000000      7.0             8           2.835940
# 5    65.35  0.000000       0.000000      2.0            10           1.992188
# 6    60.30  0.000000       0.000000      1.0            77           1.671877
# 7    55.35  0.000000       0.000000     25.0            43           1.714845
# 8    50.30  2.570000       5.188774      1.0            48           1.375003
# 9    45.30  0.000000       0.000000      9.0            61           1.230473
# 10   40.40  0.459999       1.135800      3.0            62           1.308597
# 11   35.30  0.000000       0.000000      5.0           103           1.011724
# 12   30.25  0.600000       1.973685     20.0           596           0.871095
# 13   27.75  0.000000       0.000000      1.0            38           0.757815
# 14   25.35  0.900000       3.607213     16.0           519           0.796877
# 15   22.80  0.000000       0.000000     27.0            37           0.667972
# 16   20.30 -0.230000      -1.121949    128.0           829           0.628910
# 17   17.80  0.990000       5.527637      5.0           122           0.558598
# 18   15.30  0.160000       1.051939     92.0          2562           0.507817
# 19   12.85  0.660000       5.301204     23.0           639           0.504888
# 20   10.35 -0.280000      -2.666664    160.0          6440           0.422857
# 21    7.80 -0.350000      -4.347831     99.0          1212           0.320319
# 22    5.35 -0.270000      -4.891304   5661.0         17536           0.252449
# 23    2.94 -0.200000      -6.250001   1166.0          6814           0.178719
# 24    1.13 -0.270000     -19.424460  16885.0         25417           0.156747
# 25    0.26 -0.110000     -29.729733  36922.0         31675           0.151864
# 26    0.06 -0.010000     -14.285716  12217.0         28164           0.168954
# 27    0.02  0.010000     100.000000   2732.0         21797           0.195321
# 28    0.01  0.000000       0.000000   1398.0         17927           0.230476
# 29    0.00  0.000000       0.000000      6.0          2559           0.125009
# 30    0.00  0.000000       0.000000      6.0          1629           0.250007
# 31    0.01  0.000000       0.000000      2.0           255           0.375006
# 32    0.01  0.000000       0.000000      2.0           833           0.414068
# 33    0.01  0.000000       0.000000      1.0           277           0.460943
# 34    0.01  0.000000       0.000000      2.0            85           0.500005
# 35    0.01  0.000000       0.000000     36.0           201           0.546880
# 36    0.01  0.000000       0.000000      5.0            49           0.625004
# 37    0.01  0.000000       0.000000      1.0             2           0.687503
# 38    0.01  0.000000       0.000000    102.0           104           0.781252
# 39    0.01  0.000000       0.000000      1.0           201           0.843752
# 40    0.01  0.000000       0.000000      1.0             2           0.906251
# 41    0.01  0.000000       0.000000      2.0             7           1.156254
#
#     inTheMoney contractSize currency
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD
# 5         True      REGULAR      USD
# 6         True      REGULAR      USD
# 7         True      REGULAR      USD
# 8         True      REGULAR      USD
# 9         True      REGULAR      USD
# 10        True      REGULAR      USD
# 11        True      REGULAR      USD
# 12        True      REGULAR      USD
# 13        True      REGULAR      USD
# 14        True      REGULAR      USD
# 15        True      REGULAR      USD
# 16        True      REGULAR      USD
# 17        True      REGULAR      USD
# 18        True      REGULAR      USD
# 19        True      REGULAR      USD
# 20        True      REGULAR      USD
# 21        True      REGULAR      USD
# 22        True      REGULAR      USD
# 23        True      REGULAR      USD
# 24        True      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31       False      REGULAR      USD
# 32       False      REGULAR      USD
# 33       False      REGULAR      USD
# 34       False      REGULAR      USD
# 35       False      REGULAR      USD
# 36       False      REGULAR      USD
# 37       False      REGULAR      USD
# 38       False      REGULAR      USD
# 39       False      REGULAR      USD
# 40       False      REGULAR      USD
# 41       False      REGULAR      USD

# %% [markdown]
# ## **Put Options**

# %%
# Put Options Dataframe
Apple_Stock_Data.option_chain()[1]
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL231201P00050000 2023-11-29 14:30:00+00:00    50.0       0.01   0.00
# 1   AAPL231201P00075000 2023-10-18 15:00:55+00:00    75.0       0.01   0.00
# 2   AAPL231201P00090000 2023-11-03 19:53:21+00:00    90.0       0.01   0.00
# 3   AAPL231201P00095000 2023-11-03 19:57:42+00:00    95.0       0.01   0.00
# 4   AAPL231201P00100000 2023-11-17 20:43:44+00:00   100.0       0.01   0.00
# 5   AAPL231201P00105000 2023-11-22 19:59:42+00:00   105.0       0.01   0.00
# 6   AAPL231201P00110000 2023-11-17 16:09:12+00:00   110.0       0.01   0.00
# 7   AAPL231201P00115000 2023-11-22 20:09:25+00:00   115.0       0.01   0.00
# 8   AAPL231201P00120000 2023-11-21 20:44:48+00:00   120.0       0.01   0.00
# 9   AAPL231201P00125000 2023-11-24 17:59:54+00:00   125.0       0.01   0.00
# 10  AAPL231201P00130000 2023-11-27 15:35:38+00:00   130.0       0.01   0.00
# 11  AAPL231201P00135000 2023-11-24 16:43:02+00:00   135.0       0.01   0.00
# 12  AAPL231201P00140000 2023-11-27 14:35:17+00:00   140.0       0.01   0.00
# 13  AAPL231201P00145000 2023-11-28 15:05:33+00:00   145.0       0.01   0.00
# 14  AAPL231201P00149000 2023-11-27 14:34:17+00:00   149.0       0.01   0.00
# 15  AAPL231201P00150000 2023-11-28 20:52:24+00:00   150.0       0.01   0.00
# 16  AAPL231201P00155000 2023-11-29 16:10:47+00:00   155.0       0.01   0.00
# 17  AAPL231201P00157500 2023-11-27 20:56:12+00:00   157.5       0.01   0.00
# 18  AAPL231201P00160000 2023-11-29 14:40:04+00:00   160.0       0.01   0.00
# 19  AAPL231201P00162500 2023-11-28 16:35:11+00:00   162.5       0.01   0.00
# 20  AAPL231201P00165000 2023-11-29 16:17:36+00:00   165.0       0.01   0.00
# 21  AAPL231201P00167500 2023-11-29 15:14:24+00:00   167.5       0.01   0.00
# 22  AAPL231201P00170000 2023-11-29 16:15:26+00:00   170.0       0.01   0.00
# 23  AAPL231201P00172500 2023-11-29 15:53:12+00:00   172.5       0.01   0.00
# 24  AAPL231201P00175000 2023-11-29 16:16:02+00:00   175.0       0.01   0.01
# 25  AAPL231201P00177500 2023-11-29 15:46:32+00:00   177.5       0.02   0.01
# 26  AAPL231201P00180000 2023-11-29 16:14:21+00:00   180.0       0.03   0.02
# 27  AAPL231201P00182500 2023-11-29 16:21:05+00:00   182.5       0.04   0.03
# 28  AAPL231201P00185000 2023-11-29 16:22:30+00:00   185.0       0.07   0.06
# 29  AAPL231201P00187500 2023-11-29 16:22:30+00:00   187.5       0.23   0.21
# 30  AAPL231201P00190000 2023-11-29 16:22:32+00:00   190.0       0.85   0.84
# 31  AAPL231201P00192500 2023-11-29 16:20:58+00:00   192.5       2.46   2.47
# 32  AAPL231201P00195000 2023-11-29 16:17:33+00:00   195.0       4.70   4.75
# 33  AAPL231201P00197500 2023-11-29 16:18:30+00:00   197.5       7.30   7.25
# 34  AAPL231201P00200000 2023-11-29 16:10:47+00:00   200.0       9.37   9.65
# 35  AAPL231201P00202500 2023-11-27 14:48:01+00:00   202.5      13.43  12.10
# 36  AAPL231201P00205000 2023-11-29 15:34:13+00:00   205.0      14.00  14.70
# 37  AAPL231201P00210000 2023-11-29 16:21:36+00:00   210.0      19.70  19.65
# 38  AAPL231201P00215000 2023-11-28 16:06:09+00:00   215.0      24.50  24.70
# 39  AAPL231201P00225000 2023-11-21 16:03:06+00:00   225.0      34.80  34.70
# 40  AAPL231201P00230000 2023-11-28 17:36:10+00:00   230.0      39.55  39.65
# 41  AAPL231201P00240000 2023-11-15 14:34:26+00:00   240.0      51.40  49.70
# 42  AAPL231201P00250000 2023-10-20 13:49:58+00:00   250.0      74.65  60.15
# 43  AAPL231201P00265000 2023-11-27 14:55:37+00:00   265.0      75.80  74.65
#
#       ask  change  percentChange   volume  openInterest  impliedVolatility  \
# 0    0.01    0.00       0.000000     21.0             4           4.500004
# 1    0.01    0.00       0.000000      NaN            25           3.125002
# 2    0.01    0.00       0.000000      1.0           103           2.562504
# 3    0.01    0.00       0.000000     24.0            86           2.375004
# 4    0.01    0.00       0.000000     10.0           174           2.187505
# 5    0.00    0.00       0.000000    348.0           401           0.500005
# 6    0.01    0.00       0.000000    200.0           258           1.875001
# 7    0.01    0.00       0.000000    200.0           534           1.750001
# 8    0.01    0.00       0.000000      2.0           157           1.625002
# 9    0.01    0.00       0.000000   7005.0         13710           1.500002
# 10   0.01    0.00       0.000000      3.0          9887           1.343753
# 11   0.01    0.00       0.000000    586.0          1190           1.218754
# 12   0.01    0.00       0.000000      5.0          1742           1.093755
# 13   0.01    0.00       0.000000      5.0          1341           0.968750
# 14   0.01    0.00       0.000000    499.0          1536           0.906251
# 15   0.01    0.00       0.000000      1.0          2774           0.875001
# 16   0.01    0.00       0.000000      1.0          5313           0.750003
# 17   0.01    0.00       0.000000    650.0          1137           0.703128
# 18   0.01    0.00       0.000000      9.0         13056           0.656253
# 19   0.01    0.00       0.000000     82.0           767           0.593754
# 20   0.01    0.00       0.000000     57.0          4421           0.546880
# 21   0.00    0.00       0.000000      8.0          2615           0.250007
# 22   0.01   -0.01     -50.000000    630.0          8880           0.468755
# 23   0.01    0.00       0.000000    330.0          7907           0.414068
# 24   0.02   -0.01     -50.000000     63.0         13462           0.390631
# 25   0.02   -0.02     -50.000000     58.0          5448           0.332038
# 26   0.03   -0.01     -25.000000    477.0         17433           0.287117
# 27   0.04   -0.02     -33.333336    578.0          6520           0.234383
# 28   0.07   -0.03     -30.000002   4068.0         53247           0.187508
# 29   0.22   -0.04     -14.814816  11465.0         21008           0.155282
# 30   0.85   -0.08      -8.602149  29184.0         15776           0.135751
# 31   2.50    0.00       0.000000  10189.0         10997           0.128427
# 32   4.85   -0.05      -1.052636    606.0           591           0.138680
# 33   7.35   -0.01      -0.136796     33.0           166           0.195321
# 34   9.80   -0.47      -4.776425      6.0            18           0.000010
# 35  12.30    0.00       0.000000      1.0             2           0.000010
# 36  14.85   -1.15      -7.590757     60.0             0           0.351569
# 37  19.80   -0.15      -0.755666     30.0             0           0.000010
# 38  24.85    0.00       0.000000      3.0             2           0.542973
# 39  34.95    0.00       0.000000      NaN             0           0.898439
# 40  39.90    0.00       0.000000      2.0             1           0.925782
# 41  49.95    0.00       0.000000      NaN             0           1.179692
# 42  60.45    0.00       0.000000     10.0             0           1.674806
# 43  74.80    0.00       0.000000      2.0             0           0.000010
#
#     inTheMoney contractSize currency
# 0        False      REGULAR      USD
# 1        False      REGULAR      USD
# 2        False      REGULAR      USD
# 3        False      REGULAR      USD
# 4        False      REGULAR      USD
# 5        False      REGULAR      USD
# 6        False      REGULAR      USD
# 7        False      REGULAR      USD
# 8        False      REGULAR      USD
# 9        False      REGULAR      USD
# 10       False      REGULAR      USD
# 11       False      REGULAR      USD
# 12       False      REGULAR      USD
# 13       False      REGULAR      USD
# 14       False      REGULAR      USD
# 15       False      REGULAR      USD
# 16       False      REGULAR      USD
# 17       False      REGULAR      USD
# 18       False      REGULAR      USD
# 19       False      REGULAR      USD
# 20       False      REGULAR      USD
# 21       False      REGULAR      USD
# 22       False      REGULAR      USD
# 23       False      REGULAR      USD
# 24       False      REGULAR      USD
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 30       False      REGULAR      USD
# 31        True      REGULAR      USD
# 32        True      REGULAR      USD
# 33        True      REGULAR      USD
# 34        True      REGULAR      USD
# 35        True      REGULAR      USD
# 36        True      REGULAR      USD
# 37        True      REGULAR      USD
# 38        True      REGULAR      USD
# 39        True      REGULAR      USD
# 40        True      REGULAR      USD
# 41        True      REGULAR      USD
# 42        True      REGULAR      USD
# 43        True      REGULAR      USD

# %% [markdown]
# ## **Get 5 Calls Around The Last Price**

# %%
Apple_Last_Price = Apple_Stock_Data.basic_info['lastPrice']
Apple_Last_Price
# Out:
# 190.06500244140625

# %%
# Call Options Above Last Price
Apple_Call_Options_Above_LP = Apple_Call_Options[Apple_Call_Options['strike']>Apple_Last_Price].iloc[:5]
Apple_Call_Options_Above_LP
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 25  AAPL231201C00192500 2023-11-29 16:30:07+00:00   192.5       0.26  0.25
# 26  AAPL231201C00195000 2023-11-29 16:29:36+00:00   195.0       0.06  0.05
# 27  AAPL231201C00197500 2023-11-29 16:23:11+00:00   197.5       0.02  0.01
# 28  AAPL231201C00200000 2023-11-29 16:21:33+00:00   200.0       0.01  0.00
# 29  AAPL231201C00202500 2023-11-29 15:08:09+00:00   202.5       0.01  0.00
#
#      ask  change  percentChange   volume  openInterest  impliedVolatility  \
# 25  0.26   -0.11     -29.729733  36922.0         31675           0.151864
# 26  0.06   -0.01     -14.285716  12217.0         28164           0.168954
# 27  0.02    0.01     100.000000   2732.0         21797           0.195321
# 28  0.01    0.00       0.000000   1398.0         17927           0.230476
# 29  0.00    0.00       0.000000      6.0          2559           0.125009
#
#     inTheMoney contractSize currency
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD

# %%
# Call Options Below Last Price
Apple_Call_Options_Below_LP = Apple_Call_Options[Apple_Call_Options['strike']<Apple_Last_Price].iloc[:5]
Apple_Call_Options_Below_LP
# Out:
#         contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 0  AAPL231201C00050000 2023-11-28 17:19:29+00:00    50.0     141.70  140.05
# 1  AAPL231201C00075000 2023-10-31 18:17:13+00:00    75.0      95.40  114.95
# 2  AAPL231201C00085000 2023-11-21 16:41:12+00:00    85.0     105.03  105.00
# 3  AAPL231201C00090000 2023-11-21 16:41:12+00:00    90.0     100.02  100.20
# 4  AAPL231201C00100000 2023-11-24 17:43:25+00:00   100.0      89.65   90.05
#
#       ask    change  percentChange  volume  openInterest  impliedVolatility  \
# 0  140.20  1.050003       0.746536     1.0             9           5.031254
# 1  115.25  0.000000       0.000000     NaN             0           4.367192
# 2  105.25  0.000000       0.000000     1.0             4           3.093752
# 3  100.45  0.000000       0.000000     NaN             1           3.765626
# 4   90.30  0.000000       0.000000     7.0             8           2.835940
#
#    inTheMoney contractSize currency
# 0        True      REGULAR      USD
# 1        True      REGULAR      USD
# 2        True      REGULAR      USD
# 3        True      REGULAR      USD
# 4        True      REGULAR      USD

# %%
# Apple Options Around The Last Price
Apple_Call_Options_Around_LP = pd.concat([Apple_Call_Options_Above_LP,Apple_Call_Options_Below_LP],axis=0)
Apple_Call_Options_Around_LP
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 25  AAPL231201C00192500 2023-11-29 16:30:07+00:00   192.5       0.26    0.25
# 26  AAPL231201C00195000 2023-11-29 16:29:36+00:00   195.0       0.06    0.05
# 27  AAPL231201C00197500 2023-11-29 16:23:11+00:00   197.5       0.02    0.01
# 28  AAPL231201C00200000 2023-11-29 16:21:33+00:00   200.0       0.01    0.00
# 29  AAPL231201C00202500 2023-11-29 15:08:09+00:00   202.5       0.01    0.00
# 0   AAPL231201C00050000 2023-11-28 17:19:29+00:00    50.0     141.70  140.05
# 1   AAPL231201C00075000 2023-10-31 18:17:13+00:00    75.0      95.40  114.95
# 2   AAPL231201C00085000 2023-11-21 16:41:12+00:00    85.0     105.03  105.00
# 3   AAPL231201C00090000 2023-11-21 16:41:12+00:00    90.0     100.02  100.20
# 4   AAPL231201C00100000 2023-11-24 17:43:25+00:00   100.0      89.65   90.05
#
#        ask    change  percentChange   volume  openInterest  impliedVolatility  \
# 25    0.26 -0.110000     -29.729733  36922.0         31675           0.151864
# 26    0.06 -0.010000     -14.285716  12217.0         28164           0.168954
# 27    0.02  0.010000     100.000000   2732.0         21797           0.195321
# 28    0.01  0.000000       0.000000   1398.0         17927           0.230476
# 29    0.00  0.000000       0.000000      6.0          2559           0.125009
# 0   140.20  1.050003       0.746536      1.0             9           5.031254
# 1   115.25  0.000000       0.000000      NaN             0           4.367192
# 2   105.25  0.000000       0.000000      1.0             4           3.093752
# 3   100.45  0.000000       0.000000      NaN             1           3.765626
# 4    90.30  0.000000       0.000000      7.0             8           2.835940
#
#     inTheMoney contractSize currency
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD
# 28       False      REGULAR      USD
# 29       False      REGULAR      USD
# 0         True      REGULAR      USD
# 1         True      REGULAR      USD
# 2         True      REGULAR      USD
# 3         True      REGULAR      USD
# 4         True      REGULAR      USD

# %%
# Flip The Dataframe
Apple_Call_Options_Around_LP = Apple_Call_Options_Around_LP[::-1]
Apple_Call_Options_Around_LP
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice     bid  \
# 4   AAPL231201C00100000 2023-11-24 17:43:25+00:00   100.0      89.65   90.05
# 3   AAPL231201C00090000 2023-11-21 16:41:12+00:00    90.0     100.02  100.20
# 2   AAPL231201C00085000 2023-11-21 16:41:12+00:00    85.0     105.03  105.00
# 1   AAPL231201C00075000 2023-10-31 18:17:13+00:00    75.0      95.40  114.95
# 0   AAPL231201C00050000 2023-11-28 17:19:29+00:00    50.0     141.70  140.05
# 29  AAPL231201C00202500 2023-11-29 15:08:09+00:00   202.5       0.01    0.00
# 28  AAPL231201C00200000 2023-11-29 16:21:33+00:00   200.0       0.01    0.00
# 27  AAPL231201C00197500 2023-11-29 16:23:11+00:00   197.5       0.02    0.01
# 26  AAPL231201C00195000 2023-11-29 16:29:36+00:00   195.0       0.06    0.05
# 25  AAPL231201C00192500 2023-11-29 16:30:07+00:00   192.5       0.26    0.25
#
#        ask    change  percentChange   volume  openInterest  impliedVolatility  \
# 4    90.30  0.000000       0.000000      7.0             8           2.835940
# 3   100.45  0.000000       0.000000      NaN             1           3.765626
# 2   105.25  0.000000       0.000000      1.0             4           3.093752
# 1   115.25  0.000000       0.000000      NaN             0           4.367192
# 0   140.20  1.050003       0.746536      1.0             9           5.031254
# 29    0.00  0.000000       0.000000      6.0          2559           0.125009
# 28    0.01  0.000000       0.000000   1398.0         17927           0.230476
# 27    0.02  0.010000     100.000000   2732.0         21797           0.195321
# 26    0.06 -0.010000     -14.285716  12217.0         28164           0.168954
# 25    0.26 -0.110000     -29.729733  36922.0         31675           0.151864
#
#     inTheMoney contractSize currency
# 4         True      REGULAR      USD
# 3         True      REGULAR      USD
# 2         True      REGULAR      USD
# 1         True      REGULAR      USD
# 0         True      REGULAR      USD
# 29       False      REGULAR      USD
# 28       False      REGULAR      USD
# 27       False      REGULAR      USD
# 26       False      REGULAR      USD
# 25       False      REGULAR      USD

# %% [markdown]
# ## **Largest Interests**

# %%
Apple_Call_Options_Around_LP.nlargest(3,'openInterest')
# Out:
#          contractSymbol             lastTradeDate  strike  lastPrice   bid  \
# 25  AAPL231201C00192500 2023-11-29 16:30:07+00:00   192.5       0.26  0.25
# 26  AAPL231201C00195000 2023-11-29 16:29:36+00:00   195.0       0.06  0.05
# 27  AAPL231201C00197500 2023-11-29 16:23:11+00:00   197.5       0.02  0.01
#
#      ask  change  percentChange   volume  openInterest  impliedVolatility  \
# 25  0.26   -0.11     -29.729733  36922.0         31675           0.151864
# 26  0.06   -0.01     -14.285716  12217.0         28164           0.168954
# 27  0.02    0.01     100.000000   2732.0         21797           0.195321
#
#     inTheMoney contractSize currency
# 25       False      REGULAR      USD
# 26       False      REGULAR      USD
# 27       False      REGULAR      USD

# %% [markdown]
# # **Evaluate Sector Data**
# * https://www.sectorspdrs.com/

# %% [markdown]
# ## **Get Sector Data**

# %%
# Get Sector Data
df = pd.read_csv('index-holdings-xlk.csv',skiprows=1)

print(df.shape)
df.head()
# Out:
# (64, 8)
#   Symbol    Company Name Index Weight    Last  Change %Change   Volume  \
# 0   MSFT  Microsoft Corp       24.56%  377.73   -4.97  -1.30%  11.61 M
# 1   AAPL      Apple Inc.       22.93%  190.08   -0.32  -0.17%  14.98 M
# 2   AVGO    Broadcom Inc        4.62%  940.63   -5.72  -0.60%   1.07 M
# 3   NVDA     Nvidia Corp        4.40%  480.78    2.57  +0.54%   19.3 M
# 4   ADBE      Adobe Inc.        3.16%  620.69   -2.64  -0.42%   0.83 M
#
#      52 Week Range
# 0  219.35 - 383.00
# 1  124.17 - 198.23
# 2  514.83 - 999.87
# 3  138.84 - 505.48
# 4  318.60 - 625.83

# %% [markdown]
# ## **Get Sector Stocks**

# %%
Tech_Stocks = list(df['Symbol'].values)

print('No. Of Tech Stocks: ',len(Tech_Stocks))
print(Tech_Stocks)
# Out:
# No. Of Tech Stocks:  64
# ['MSFT', 'AAPL', 'AVGO', 'NVDA', 'ADBE', 'CRM', 'ACN', 'AMD', 'CSCO', 'INTC', 'ORCL', 'INTU', 'IBM', 'QCOM', 'TXN', 'NOW', 'AMAT', 'LRCX', 'ADI', 'PANW', 'MU', 'SNPS', 'KLAC', 'CDNS', 'ROP', 'ANET', 'APH', 'MSI', 'NXPI', 'MCHP', 'ADSK', 'TEL', 'CTSH', 'FTNT', 'IT', 'ON', 'CDW', 'FICO', 'MPWR', 'ANSS', 'HPQ', 'KEYS', 'GLW', 'HPE', 'VRSN', 'TDY', 'PTC', 'AKAM', 'TYL', 'FSLR', 'NTAP', 'SWKS', 'WDC', 'EPAM', 'STX', 'TER', 'ENPH', 'ZBRA', 'GEN', 'TRMB', 'FFIV', 'QRVO', 'JNPR', 'SEDG']

# %% [markdown]
# ## **Get Tech Stock PE Ratios**

# %%
Portfolio = []

for stock in Tech_Stocks:
    try:
        Stock_PE = yf.Ticker(stock).get_info()['trailingPE']
        Portfolio.append((stock,Stock_PE))
    except: 
        pass

# %%
print(Portfolio)
# Out:
# [('MSFT', 36.77154), ('AAPL', 30.855629), ('AVGO', 29.087801), ('NVDA', 63.34408), ('ADBE', 55.91216), ('CRM', 144.28125), ('ACN', 30.941502), ('AMD', 1127.0591), ('CSCO', 14.531632), ('ORCL', 34.525223), ('INTU', 63.43771), ('IBM', 20.194838), ('QCOM', 19.646473), ('TXN', 19.887306), ('NOW', 88.03886), ('AMAT', 18.429249), ('LRCX', 24.303934), ('ADI', 27.926828), ('PANW', 163.16855), ('SNPS', 83.56009), ('KLAC', 24.339588), ('CDNS', 78.42898), ('ROP', 45.506485), ('ANET', 36.416943), ('APH', 29.109678), ('MSI', 32.237373), ('NXPI', 18.989332), ('MCHP', 18.252193), ('ADSK', 51.055553), ('TEL', 21.774542), ('CTSH', 17.085367), ('FTNT', 37.29514), ('IT', 37.165318), ('ON', 14.4838705), ('CDW', 26.465086), ('FICO', 63.259438), ('MPWR', 59.66721), ('ANSS', 53.823105), ('HPQ', 8.90951), ('KEYS', 21.95382), ('GLW', 41.40441), ('HPE', 19.981928), ('VRSN', 30.323572), ('TDY', 24.188223), ('PTC', 75.92683), ('AKAM', 34.984898), ('TYL', 110.25876), ('FSLR', 35.25113), ('NTAP', 16.35145), ('SWKS', 15.750408), ('EPAM', 32.64259), ('TER', 43.348835), ('ENPH', 25.49624), ('ZBRA', 26.5452), ('GEN', 9.7488785), ('TRMB', 34.105556), ('FFIV', 25.945122), ('JNPR', 24.941963), ('SEDG', 21.472971)]

# %%
Portfolio_PE_Ratio = pd.DataFrame(Portfolio,columns=['Stock','PE_Ratio'])
Portfolio_PE_Ratio.head()
# Out:
#   Stock   PE_Ratio
# 0  MSFT  36.771540
# 1  AAPL  30.855629
# 2  AVGO  29.087801
# 3  NVDA  63.344080
# 4  ADBE  55.912160

# %%
# Statistical Summary Of PE_Ratios
Portfolio_PE_Ratio['PE_Ratio'].describe()
# Out:
# count      59.000000
# mean       58.318496
# std       144.674441
# min         8.909510
# 25%        21.623756
# 50%        30.855629
# 75%        48.281019
# max      1127.059100
# Name: PE_Ratio, dtype: float64

# %% [markdown]
# ## **Determine Stock Valuation**

# %%
sns.scatterplot(data=Portfolio_PE_Ratio,x='Stock',y='PE_Ratio')
# Out:
# <Axes: xlabel='Stock', ylabel='PE_Ratio'>

# %%
Portfolio_PE_Ratio['PE_Ratio'].mean()

# %%
Portfolio_PE_Ratio.index[-1]
# Out:
# 58

# %%
plt.figure(figsize=(16,6))
plt.scatter(x=Portfolio_PE_Ratio['Stock'],y=Portfolio_PE_Ratio['PE_Ratio'],
            c=Portfolio_PE_Ratio['PE_Ratio'],s=Portfolio_PE_Ratio['PE_Ratio'])
plt.hlines(y=50,xmin=Portfolio_PE_Ratio.index[0],xmax=Portfolio_PE_Ratio.index[-1],
            linestyles='dashed',colors='red')
plt.xticks(rotation=45)
plt.colorbar()
plt.title('Technology Stocks - PE Ratios')
# Out:
# Text(0.5, 1.0, 'Technology Stocks - PE Ratios')

# %% [markdown]
# # **Get Market Cap Data**

# %% [markdown]
# ## **Yahoo_fin Package**

# %%
Apple_Valuation = si.get_stats_valuation('AAPL')
Apple_Valuation
# Out:
# c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\yahoo_fin\stock_info.py:357: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(requests.get(stats_site, headers=headers).text)
#                            0      1
# 0      Market Cap (intraday)  2.96T
# 1           Enterprise Value  3.01T
# 2               Trailing P/E  31.06
# 3                Forward P/E  28.90
# 4  PEG Ratio (5 yr expected)   2.25
# 5          Price/Sales (ttm)   7.86
# 6           Price/Book (mrq)  47.65
# 7   Enterprise Value/Revenue   7.86
# 8    Enterprise Value/EBITDA  23.31

# %% [markdown]
# ## **Get DOW Stocks List**

# %%
DOW_Stocks = si.tickers_dow()

print('No. Of DOW Stocks: ',len(DOW_Stocks))
print(DOW_Stocks)
# Out:
# No. Of DOW Stocks:  30
# ['AAPL', 'AMGN', 'AXP', 'BA', 'CAT', 'CRM', 'CSCO', 'CVX', 'DIS', 'DOW', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'JPM', 'KO', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'V', 'VZ', 'WBA', 'WMT']

# %%
si.get_stats_valuation('AMGN')
# Out:
# c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\yahoo_fin\stock_info.py:357: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tables = pd.read_html(requests.get(stats_site, headers=headers).text)
#                            0        1
# 0      Market Cap (intraday)  142.10B
# 1           Enterprise Value  167.83B
# 2               Trailing P/E    18.88
# 3                Forward P/E    13.59
# 4  PEG Ratio (5 yr expected)     2.16
# 5          Price/Sales (ttm)     5.32
# 6           Price/Book (mrq)    18.56
# 7   Enterprise Value/Revenue     6.25
# 8    Enterprise Value/EBITDA    11.32

# %%
si.get_stats_valuation('AMGN').loc[:,0].values
# Out:
# array(['Market Cap (intraday)', 'Enterprise Value', 'Trailing P/E',
#        'Forward P/E', 'PEG Ratio (5 yr expected)', 'Price/Sales (ttm)',
#        'Price/Book (mrq)', 'Enterprise Value/Revenue',
#        'Enterprise Value/EBITDA'], dtype=object)

# %%
DOW_Stock_Stats = pd.DataFrame()
DOW_Stock_Stats.index = ['Market Cap (intraday)', 'Enterprise Value', 'Trailing P/E',
       'Forward P/E', 'PEG Ratio (5 yr expected)', 'Price/Sales (ttm)',
       'Price/Book (mrq)', 'Enterprise Value/Revenue',
       'Enterprise Value/EBITDA']
for stock in DOW_Stocks:
    print('Fetching Data For :',stock)
    stock_stats = si.get_stats_valuation(stock)
    print(stock_stats)
    clear_output(wait=True)
    DOW_Stock_Stats[stock] = list(stock_stats.loc[:,1].values)
# Out:
# Fetching Data For : WMT
#                            0        1
# 0      Market Cap (intraday)  426.99B
# 1           Enterprise Value  484.57B
# 2               Trailing P/E    26.40
# 3                Forward P/E    22.47
# 4  PEG Ratio (5 yr expected)     2.78
# 5          Price/Sales (ttm)     0.67
# 6           Price/Book (mrq)     5.37
# 7   Enterprise Value/Revenue     0.76
# 8    Enterprise Value/EBITDA    12.96

# %%
DOW_Stock_Stats
# Out:
#                             AAPL     AMGN      AXP       BA      CAT      CRM  \
# Market Cap (intraday)      2.96T  142.10B  120.72B  134.53B  126.00B  218.85B
# Enterprise Value           3.01T  167.83B      NaN  173.43B  156.59B  219.25B
# Trailing P/E               31.06    18.88    15.53      NaN    14.03   140.57
# Forward P/E                28.90    13.59    13.35    55.56    12.06    23.87
# PEG Ratio (5 yr expected)   2.25     2.16     1.03     6.53     1.47     1.19
# Price/Sales (ttm)           7.86     5.32     2.10     1.77     1.92     6.73
# Price/Book (mrq)           47.65    18.56     4.42      NaN     6.15     3.77
# Enterprise Value/Revenue    7.86     6.25      NaN     2.29     2.35     6.63
# Enterprise Value/EBITDA    23.31    11.32      NaN   101.54    10.76    26.07
#
#                               CSCO      CVX      DIS     DOW  ...      MRK  \
# Market Cap (intraday)      194.44B  274.69B  169.30B  36.26B  ...  253.86B
# Enterprise Value           178.56B  289.31B  201.55B  49.45B  ...  279.94B
# Trailing P/E                 14.46    10.80    71.71   28.09  ...    55.66
# Forward P/E                  12.33    10.14    19.68   13.70  ...    11.72
# PEG Ratio (5 yr expected)     2.94      NaN     1.11    4.61  ...     0.80
# Price/Sales (ttm)             3.38     1.36     1.90    0.80  ...     4.30
# Price/Book (mrq)              4.30     1.66     1.71    1.85  ...     6.15
# Enterprise Value/Revenue      3.08     1.43     2.27    1.08  ...     4.72
# Enterprise Value/EBITDA       9.69     5.48    16.64    9.50  ...    22.72
#
#                             MSFT      NKE       PG     TRV      UNH        V  \
# Market Cap (intraday)      2.84T  165.51B  358.93B  40.39B  499.95B  519.37B
# Enterprise Value           2.79T  168.89B  385.89B  47.83B  519.22B  519.71B
# Trailing P/E               37.08    33.56    24.72   19.10    23.46    30.55
# Forward P/E                34.72    29.41    23.92   10.08    19.27    25.58
# PEG Ratio (5 yr expected)   2.32     1.98     3.52    0.57     1.54     1.63
# Price/Sales (ttm)          13.09     3.29     4.53    1.03     1.41    16.15
# Price/Book (mrq)           12.89    11.85     7.66    2.02     5.92    13.41
# Enterprise Value/Revenue   12.76     3.28     4.63    1.19     1.44    15.92
# Enterprise Value/EBITDA    24.87    25.17    16.95     NaN    14.61    22.97
#
#                                 VZ     WBA      WMT
# Market Cap (intraday)      157.53B  17.26B  426.99B
# Enterprise Value           325.39B  50.06B  484.57B
# Trailing P/E                  7.54    5.98    26.40
# Forward P/E                   8.06    5.98    22.47
# PEG Ratio (5 yr expected)     6.72    5.92     2.78
# Price/Sales (ttm)             1.18    0.12     0.67
# Price/Book (mrq)              1.61    0.86     5.37
# Enterprise Value/Revenue      2.43    0.36     0.76
# Enterprise Value/EBITDA       6.51  -19.39    12.96
#
# [9 rows x 30 columns]

# %%
# Transpose Dataframe
DOW_Stock_Stats = DOW_Stock_Stats.T
DOW_Stock_Stats.head()
# Out:
#      Market Cap (intraday) Enterprise Value Trailing P/E Forward P/E  \
# AAPL                 2.96T            3.01T        31.06       28.90
# AMGN               142.10B          167.83B        18.88       13.59
# AXP                120.72B              NaN        15.53       13.35
# BA                 134.53B          173.43B          NaN       55.56
# CAT                126.00B          156.59B        14.03       12.06
# CRM                218.85B          219.25B       140.57       23.87
# CSCO               194.44B          178.56B        14.46       12.33
# CVX                274.69B          289.31B        10.80       10.14
# DIS                169.30B          201.55B        71.71       19.68
# DOW                 36.26B           49.45B        28.09       13.70
# GS                 110.11B              NaN        16.28        9.50
# HD                 311.86B          359.05B        20.09       19.57
# HON                128.07B          140.42B        24.07       19.42
# IBM                142.13B          189.67B        20.08       15.58
# INTC               186.47B          210.32B          NaN       24.45
# JNJ                365.02B          371.43B        28.45       13.99
# JPM                443.89B              NaN         9.16       10.08
# KO                 253.27B          278.00B        23.72       20.92
# MCD                204.61B          250.87B        24.88       22.62
# MMM                 54.41B           65.99B        16.99       10.27
# MRK                253.86B          279.94B        55.66       11.72
# MSFT                 2.84T            2.79T        37.08       34.72
# NKE                165.51B          168.89B        33.56       29.41
# PG                 358.93B          385.89B        24.72       23.92
# TRV                 40.39B           47.83B        19.10       10.08
# UNH                499.95B          519.22B        23.46       19.27
# V                  519.37B          519.71B        30.55       25.58
# VZ                 157.53B          325.39B         7.54        8.06
# WBA                 17.26B           50.06B         5.98        5.98
# WMT                426.99B          484.57B        26.40       22.47
#
#      PEG Ratio (5 yr expected) Price/Sales (ttm) Price/Book (mrq)  \
# AAPL                      2.25              7.86            47.65
# AMGN                      2.16              5.32            18.56
# AXP                       1.03              2.10             4.42
# BA                        6.53              1.77              NaN
# CAT                       1.47              1.92             6.15
# CRM                       1.19              6.73             3.77
# CSCO                      2.94              3.38             4.30
# CVX                        NaN              1.36             1.66
# DIS                       1.11              1.90             1.71
# DOW                       4.61              0.80             1.85
# GS                        2.64              2.59             1.04
# HD                        1.92              2.05           218.08
# HON                       1.98              3.59             7.43
# IBM                       0.42              2.36             6.16
# INTC                      1.17              3.49             1.83
# JNJ                       1.50              4.02             5.12
# JPM                       3.06              3.01             1.53
# KO                        2.76              5.65             9.62
# MCD                       1.86              8.28              NaN
# MMM                       3.62              1.66            11.65
# MRK                       0.80              4.30             6.15
# MSFT                      2.32             13.09            12.89
# NKE                       1.98              3.29            11.85
# PG                        3.52              4.53             7.66
# TRV                       0.57              1.03             2.02
# UNH                       1.54              1.41             5.92
# V                         1.63             16.15            13.41
# VZ                        6.72              1.18             1.61
# WBA                       5.92              0.12             0.86
# WMT                       2.78              0.67             5.37
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA
# AAPL                     7.86                   23.31
# AMGN                     6.25                   11.32
# AXP                       NaN                     NaN
# BA                       2.29                  101.54
# CAT                      2.35                   10.76
# CRM                      6.63                   26.07
# CSCO                     3.08                    9.69
# CVX                      1.43                    5.48
# DIS                      2.27                   16.64
# DOW                      1.08                    9.50
# GS                        NaN                     NaN
# HD                       2.34                   14.00
# HON                      3.86                   16.10
# IBM                      3.10                   13.41
# INTC                     3.98                   25.30
# JNJ                      3.76                   15.06
# JPM                       NaN                     NaN
# KO                       6.17                   17.88
# MCD                     10.03                   18.43
# MMM                      2.02                   -8.80
# MRK                      4.72                   22.72
# MSFT                    12.76                   24.87
# NKE                      3.28                   25.17
# PG                       4.63                   16.95
# TRV                      1.19                     NaN
# UNH                      1.44                   14.61
# V                       15.92                   22.97
# VZ                       2.43                    6.51
# WBA                      0.36                  -19.39
# WMT                      0.76                   12.96

# %%
# Convert Market Cap Values To Floats in Billion
DOW_Stock_Stats['Market Cap (intraday)'] = DOW_Stock_Stats['Market Cap (intraday)'].apply(lambda x:float(x.strip('T'))*1000 if 'T' in x else float(x.strip('B')))
DOW_Stock_Stats.head(10)
# Out:
#       Market Cap (intraday) Enterprise Value Trailing P/E Forward P/E  \
# AAPL                2960.00            3.01T        31.06       28.90
# AMGN                 142.10          167.83B        18.88       13.59
# AXP                  120.72              NaN        15.53       13.35
# BA                   134.53          173.43B          NaN       55.56
# CAT                  126.00          156.59B        14.03       12.06
# CRM                  218.85          219.25B       140.57       23.87
# CSCO                 194.44          178.56B        14.46       12.33
# CVX                  274.69          289.31B        10.80       10.14
# DIS                  169.30          201.55B        71.71       19.68
# DOW                   36.26           49.45B        28.09       13.70
#
#      PEG Ratio (5 yr expected) Price/Sales (ttm) Price/Book (mrq)  \
# AAPL                      2.25              7.86            47.65
# AMGN                      2.16              5.32            18.56
# AXP                       1.03              2.10             4.42
# BA                        6.53              1.77              NaN
# CAT                       1.47              1.92             6.15
# CRM                       1.19              6.73             3.77
# CSCO                      2.94              3.38             4.30
# CVX                        NaN              1.36             1.66
# DIS                       1.11              1.90             1.71
# DOW                       4.61              0.80             1.85
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA
# AAPL                     7.86                   23.31
# AMGN                     6.25                   11.32
# AXP                       NaN                     NaN
# BA                       2.29                  101.54
# CAT                      2.35                   10.76
# CRM                      6.63                   26.07
# CSCO                     3.08                    9.69
# CVX                      1.43                    5.48
# DIS                      2.27                   16.64
# DOW                      1.08                    9.50

# %%
DOW_Stock_Stats.rename({'Market Cap (intraday)':'Market Cap'},axis=1,inplace=True)
DOW_Stock_Stats.head()
# Out:
#       Market Cap Enterprise Value Trailing P/E Forward P/E  \
# AAPL     2960.00            3.01T        31.06       28.90
# AMGN      142.10          167.83B        18.88       13.59
# AXP       120.72              NaN        15.53       13.35
# BA        134.53          173.43B          NaN       55.56
# CAT       126.00          156.59B        14.03       12.06
# CRM       218.85          219.25B       140.57       23.87
# CSCO      194.44          178.56B        14.46       12.33
# CVX       274.69          289.31B        10.80       10.14
# DIS       169.30          201.55B        71.71       19.68
# DOW        36.26           49.45B        28.09       13.70
# GS        110.11              NaN        16.28        9.50
# HD        311.86          359.05B        20.09       19.57
# HON       128.07          140.42B        24.07       19.42
# IBM       142.13          189.67B        20.08       15.58
# INTC      186.47          210.32B          NaN       24.45
# JNJ       365.02          371.43B        28.45       13.99
# JPM       443.89              NaN         9.16       10.08
# KO        253.27          278.00B        23.72       20.92
# MCD       204.61          250.87B        24.88       22.62
# MMM        54.41           65.99B        16.99       10.27
# MRK       253.86          279.94B        55.66       11.72
# MSFT     2840.00            2.79T        37.08       34.72
# NKE       165.51          168.89B        33.56       29.41
# PG        358.93          385.89B        24.72       23.92
# TRV        40.39           47.83B        19.10       10.08
# UNH       499.95          519.22B        23.46       19.27
# V         519.37          519.71B        30.55       25.58
# VZ        157.53          325.39B         7.54        8.06
# WBA        17.26           50.06B         5.98        5.98
# WMT       426.99          484.57B        26.40       22.47
#
#      PEG Ratio (5 yr expected) Price/Sales (ttm) Price/Book (mrq)  \
# AAPL                      2.25              7.86            47.65
# AMGN                      2.16              5.32            18.56
# AXP                       1.03              2.10             4.42
# BA                        6.53              1.77              NaN
# CAT                       1.47              1.92             6.15
# CRM                       1.19              6.73             3.77
# CSCO                      2.94              3.38             4.30
# CVX                        NaN              1.36             1.66
# DIS                       1.11              1.90             1.71
# DOW                       4.61              0.80             1.85
# GS                        2.64              2.59             1.04
# HD                        1.92              2.05           218.08
# HON                       1.98              3.59             7.43
# IBM                       0.42              2.36             6.16
# INTC                      1.17              3.49             1.83
# JNJ                       1.50              4.02             5.12
# JPM                       3.06              3.01             1.53
# KO                        2.76              5.65             9.62
# MCD                       1.86              8.28              NaN
# MMM                       3.62              1.66            11.65
# MRK                       0.80              4.30             6.15
# MSFT                      2.32             13.09            12.89
# NKE                       1.98              3.29            11.85
# PG                        3.52              4.53             7.66
# TRV                       0.57              1.03             2.02
# UNH                       1.54              1.41             5.92
# V                         1.63             16.15            13.41
# VZ                        6.72              1.18             1.61
# WBA                       5.92              0.12             0.86
# WMT                       2.78              0.67             5.37
#
#      Enterprise Value/Revenue Enterprise Value/EBITDA
# AAPL                     7.86                   23.31
# AMGN                     6.25                   11.32
# AXP                       NaN                     NaN
# BA                       2.29                  101.54
# CAT                      2.35                   10.76
# CRM                      6.63                   26.07
# CSCO                     3.08                    9.69
# CVX                      1.43                    5.48
# DIS                      2.27                   16.64
# DOW                      1.08                    9.50
# GS                        NaN                     NaN
# HD                       2.34                   14.00
# HON                      3.86                   16.10
# IBM                      3.10                   13.41
# INTC                     3.98                   25.30
# JNJ                      3.76                   15.06
# JPM                       NaN                     NaN
# KO                       6.17                   17.88
# MCD                     10.03                   18.43
# MMM                      2.02                   -8.80
# MRK                      4.72                   22.72
# MSFT                    12.76                   24.87
# NKE                      3.28                   25.17
# PG                       4.63                   16.95
# TRV                      1.19                     NaN
# UNH                      1.44                   14.61
# V                       15.92                   22.97
# VZ                       2.43                    6.51
# WBA                      0.36                  -19.39
# WMT                      0.76                   12.96

# %% [markdown]
# ## **Plot Market Cap**

# %%
len(DOW_Stock_Stats.index)
# Out:
# 30

# %%
len(DOW_Stock_Stats.loc[:'Market Cap'])
# Out:
# 22

# %%
DOW_Stock_Stats.loc[:,'Market Cap']
# Out:
# AAPL    2960.00
# AMGN     142.10
# AXP      120.72
# BA       134.53
# CAT      126.00
# CRM      218.85
# CSCO     194.44
# CVX      274.69
# DIS      169.30
# DOW       36.26
# GS       110.11
# HD       311.86
# HON      128.07
# IBM      142.13
# INTC     186.47
# JNJ      365.02
# JPM      443.89
# KO       253.27
# MCD      204.61
# MMM       54.41
# MRK      253.86
# MSFT    2840.00
# NKE      165.51
# PG       358.93
# TRV       40.39
# UNH      499.95
# V        519.37
# VZ       157.53
# WBA       17.26
# WMT      426.99
# Name: Market Cap, dtype: float64

# %%
plt.figure(figsize=(20,6))
plt.scatter(DOW_Stock_Stats.index,DOW_Stock_Stats.loc[:,'Market Cap'],
            s=DOW_Stock_Stats.loc[:,'Market Cap'],c=DOW_Stock_Stats.loc[:,'Market Cap'])
plt.xticks(rotation=45)
plt.colorbar()
plt.title('DOW Index Stocks - Market Cap')
plt.show()

# %%
# Set Y-Limit To Exclude Apple & Microsoft
plt.figure(figsize=(20,6))
plt.scatter(DOW_Stock_Stats.index,DOW_Stock_Stats.loc[:,'Market Cap'],
            s=DOW_Stock_Stats.loc[:,'Market Cap'],c=DOW_Stock_Stats.loc[:,'Market Cap'])
plt.xticks(rotation=45)
plt.ylim((0,600))
plt.colorbar()
plt.title('DOW Index Stocks - Market Cap')
plt.show()

# %% [markdown]
# # **Technical Analysis**

# %%
MyStocks = ['AAPL','MSFT','IBM']

# %%
datetime.today()
# Out:
# datetime.datetime(2023, 11, 29, 21, 37, 29, 704042)

# %% [markdown]
# ## **Get Stock Data**

# %%
MyStocks_Tech_Data = yf.download(MyStocks,start='2020-01-01',end=datetime.today())
MyStocks_Tech_Data.head()
# Out:
# [*********************100%%**********************]  3 of 3 completed
#             Adj Close                              Close              \
#                  AAPL         IBM        MSFT       AAPL         IBM
# Date
# 2020-01-02  73.152649  106.306770  154.779541  75.087502  129.464630
# 2020-01-03  72.441444  105.458954  152.852280  74.357498  128.432129
# 2020-01-06  73.018684  105.270538  153.247360  74.949997  128.202682
# 2020-01-07  72.675285  105.341194  151.850037  74.597504  128.288712
# 2020-01-08  73.844353  106.220421  154.268799  75.797501  129.359467
#
#                              High                                Low  \
#                   MSFT       AAPL         IBM        MSFT       AAPL
# Date
# 2020-01-02  160.619995  75.150002  129.942642  160.729996  73.797501
# 2020-01-03  158.619995  75.144997  128.929260  159.949997  74.125000
# 2020-01-06  159.029999  74.989998  128.336517  159.100006  73.187500
# 2020-01-07  157.580002  75.224998  129.024857  159.669998  74.370003
# 2020-01-08  160.089996  76.110001  129.885284  160.800003  74.290001
#
#                                          Open                          \
#                    IBM        MSFT       AAPL         IBM        MSFT
# Date
# 2020-01-02  128.843216  158.330002  74.059998  129.063095  158.779999
# 2020-01-03  127.686424  158.059998  74.287498  127.695984  158.320007
# 2020-01-06  127.342255  156.509995  73.447502  127.552582  157.080002
# 2020-01-07  127.533463  157.320007  74.959999  127.810707  159.320007
# 2020-01-08  128.030594  157.949997  74.290001  128.594650  158.929993
#
#                Volume
#                  AAPL      IBM      MSFT
# Date
# 2020-01-02  135480400  3293436  22622100
# 2020-01-03  146322800  2482890  21116200
# 2020-01-06  118387200  2537073  20813700
# 2020-01-07  108872000  3232977  21634100
# 2020-01-08  132079200  4545916  27746500

# %% [markdown]
# ## **Get Adj Closing Price**

# %%
MyStocks_Tech_Data.columns
# Out:
# MultiIndex([('Adj Close', 'AAPL'),
#             ('Adj Close',  'IBM'),
#             ('Adj Close', 'MSFT'),
#             (    'Close', 'AAPL'),
#             (    'Close',  'IBM'),
#             (    'Close', 'MSFT'),
#             (     'High', 'AAPL'),
#             (     'High',  'IBM'),
#             (     'High', 'MSFT'),
#             (      'Low', 'AAPL'),
#             (      'Low',  'IBM'),
#             (      'Low', 'MSFT'),
#             (     'Open', 'AAPL'),
#             (     'Open',  'IBM'),
#             (     'Open', 'MSFT'),
#             (   'Volume', 'AAPL'),
#             (   'Volume',  'IBM'),
#             (   'Volume', 'MSFT')],
#            )

# %%
MyStocks_Tech_Data_CP = MyStocks_Tech_Data.loc[:,'Adj Close']
# Out:
#                   AAPL         IBM        MSFT
# Date
# 2020-01-02   73.152649  106.306770  154.779541
# 2020-01-03   72.441444  105.458954  152.852280
# 2020-01-06   73.018684  105.270538  153.247360
# 2020-01-07   72.675285  105.341194  151.850037
# 2020-01-08   73.844353  106.220421  154.268799
# ...                ...         ...         ...
# 2023-11-22  191.309998  155.130005  377.850006
# 2023-11-24  189.970001  155.179993  377.429993
# 2023-11-27  189.789993  155.570007  378.609985
# 2023-11-28  190.399994  155.649994  382.700012
# 2023-11-29  189.369995  156.410004  378.850006
#
# [985 rows x 3 columns]

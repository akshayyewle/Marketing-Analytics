# %% [markdown]
# # **Setup**

# %%
# !pip install nselib
# https://pypi.org/project/nselib/

import nselib
from nselib import capital_market as nse
from datetime import date

# %% [markdown]
# # **Holiday Calendar**

# %%
nselib.trading_holiday_calendar()
# Out:
#                                    Product  tradingDate    weekDay  \
# 0                          Corporate Bonds  22-Jan-2024     Monday
# 1                          Corporate Bonds  26-Jan-2024     Friday
# 2                          Corporate Bonds  19-Feb-2024     Monday
# 3                          Corporate Bonds  08-Mar-2024     Friday
# 4                          Corporate Bonds  25-Mar-2024     Monday
# ..                                     ...          ...        ...
# 15  Securities Lending & Borrowing Schemes  12-Oct-2024   Saturday
# 16  Securities Lending & Borrowing Schemes  01-Nov-2024     Friday
# 17  Securities Lending & Borrowing Schemes  02-Nov-2024   Saturday
# 18  Securities Lending & Borrowing Schemes  15-Nov-2024     Friday
# 19  Securities Lending & Borrowing Schemes  25-Dec-2024  Wednesday
#
#                              description Sr_no
# 0                      Special Holiday\r     1
# 1                         Republic Day\r     2
# ...

# %% [markdown]
# # **List Of Companies**

# %%
nse.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      BE
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 1955        ZOTA                  Zota Health Care LImited      EQ
# 1956       ZUARI              Zuari Agro Chemicals Limited      EQ
# 1957    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 1958   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 1959   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
nse.nifty50_equity_list()
# Out:
#                                   Company Name  \
# 0                       Adani Enterprises Ltd.
# 1   Adani Ports and Special Economic Zone Ltd.
# 2             Apollo Hospitals Enterprise Ltd.
# 3                            Asian Paints Ltd.
# 4                               Axis Bank Ltd.
# 5                              Bajaj Auto Ltd.
# 6                           Bajaj Finance Ltd.
# 7                           Bajaj Finserv Ltd.
# 8            Bharat Petroleum Corporation Ltd.
# 9                           Bharti Airtel Ltd.
# 10                   Britannia Industries Ltd.
# 11                                  Cipla Ltd.
# 12                             Coal India Ltd.
# 13                    Divi's Laboratories Ltd.
# 14               Dr. Reddy's Laboratories Ltd.
# 15                          Eicher Motors Ltd.
# 16                      Grasim Industries Ltd.
# 17                       HCL Technologies Ltd.
# 18                              HDFC Bank Ltd.
# ...

# %% [markdown]
# # **Bhav Copy**

# %%
# Stock Price For All The Listed Companies
nse.bhav_copy_equities(trade_date='07-03-2024')
# Out:
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0     1018GS2026     GS   116.46   117.00   116.00   116.00   116.00
# 1     182D010824     TB    96.80    96.80    96.80    96.80    96.80
# 2     182D040424     TB    98.95    98.95    98.95    98.95    98.95
# 3     182D060624     TB    98.00    98.00    98.00    98.00    98.00
# 4     182D110724     TB    96.70    97.00    96.70    97.00    97.00
# ...          ...    ...      ...      ...      ...      ...      ...
# 2699        ZOTA     EQ   503.55   512.45   503.55   504.50   506.05
# 2700       ZUARI     EQ   195.00   204.60   194.65   197.35   196.65
# 2701    ZUARIIND     EQ   285.65   291.30   278.50   284.90   284.15
# 2702   ZYDUSLIFE     EQ   962.00   981.95   958.05   976.75   977.00
# 2703   ZYDUSWELL     EQ  1576.95  1596.95  1565.00  1582.75  1589.95
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL    TIMESTAMP  TOTALTRADES
# 0        116.46       2020  2.353792e+05  07-MAR-2024            4
# ...

# %%
# Detailed Stock Prices For All The Listed Companies
nse.bhav_copy_with_delivery(trade_date='07-03-2024')
# Out:
#           SYMBOL SERIES  OPEN_PRICE  HIGH_PRICE  LOW_PRICE  CLOSE_PRICE  \
# 0     1018GS2026     GS      116.46      117.00     116.00       116.00
# 1      20MICRONS     EQ      155.55      155.75     147.00       148.70
# 2     21STCENMGM     BE       48.40       49.00      48.40        49.00
# 3         360ONE     EQ      702.55      705.10     675.85       679.80
# 4      3IINFOLTD     EQ       46.00       47.00      45.30        45.75
# ...          ...    ...         ...         ...        ...          ...
# 2625        ZOTA     EQ      503.55      512.45     503.55       504.50
# 2626       ZUARI     EQ      195.00      204.60     194.65       197.35
# 2627    ZUARIIND     EQ      285.65      291.30     278.50       284.90
# 2628   ZYDUSLIFE     EQ      962.00      981.95     958.05       976.75
# 2629   ZYDUSWELL     EQ     1576.95     1596.95    1565.00      1582.75
#
#       PREV_CLOSE  TTL_TRD_QNTY  TURNOVER_LACS  NO_OF_TRADES DELIV_QTY  \
# ...

# %% [markdown]
# # **Block & Bulk Deal**

# %%
nse.block_deals_data(from_date='01-03-2024', to_date='06-03-2020',period='1M')
# Out:
#             Date      Symbol              SecurityName  \
# 0    07-FEB-2024         BSE               BSE Limited
# 1    07-FEB-2024         BSE               BSE Limited
# 2    08-FEB-2024  KALYANKJIL  Kalyan Jewellers Ind Ltd
# 3    08-FEB-2024  KALYANKJIL  Kalyan Jewellers Ind Ltd
# 4    08-FEB-2024  KALYANKJIL  Kalyan Jewellers Ind Ltd
# ..           ...         ...                       ...
# 176  07-MAR-2024       LODHA  Macrotech Developers Ltd
# 177  07-MAR-2024  TATAMOTORS       Tata Motors Limited
# 178  07-MAR-2024  TATAMOTORS       Tata Motors Limited
# 179  07-MAR-2024  TORNTPHARM       Torrent Pharma Ltd.
# 180  07-MAR-2024  TORNTPHARM       Torrent Pharma Ltd.
#
#                                             ClientName Buy/Sell  \
# 0    MARSHALL WACE INVESTMENT STRATEGIES - SYSTEMAT...     SELL
# 1                                     SOCIETE GENERALE      BUY
# 2                                                 AEMV      BUY
# ...

# %%
# Bulk Deal
nse.bulk_deal_data(from_date='01-03-2024', to_date='06-03-2020',period='1M')
# Out:
#              Date      Symbol               SecurityName  \
# 0     07-FEB-2024     ADRO-RE    Adroit Infotech Limited
# 1     07-FEB-2024         AKG           AKG Exim Limited
# 2     07-FEB-2024         AKG           AKG Exim Limited
# 3     07-FEB-2024         AKG           AKG Exim Limited
# 4     07-FEB-2024         AKG           AKG Exim Limited
# ...           ...         ...                        ...
# 2473  07-MAR-2024    TATACHEM        Tata Chemicals Ltd.
# 2474  07-MAR-2024    TATACHEM        Tata Chemicals Ltd.
# 2475  07-MAR-2024  TOKYOPLAST       Tokyo Plast Intl Ltd
# 2476  07-MAR-2024        VETO  Veto Switchgear Cable Ltd
# 2477  07-MAR-2024        VETO  Veto Switchgear Cable Ltd
#
#                           ClientName Buy/Sell QuantityTraded  \
# 0                         ARUN  JAIN      BUY       2,00,000
# 1                   DHANDHARIA ANAND     SELL       2,14,201
# 2     MSB E TRADE SECURITIES LIMITED      BUY       1,67,500
# ...

# %% [markdown]
# # **Stock Price**

# %%
# nse.deliverable_position_data(symbol='SBIN', from_date='01-01-2024', period='1M')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\nselib\capital_market\capital_market_data.py:96, in get_price_volume_data(symbol, from_date, to_date)
#      95 with open('file.csv', 'w') as f:
# ---> 96     f.write(data_text)
#      97 f.close()
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\x82' in position 178: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# NSEdataNotFound                           Traceback (most recent call last)
# Cell In[42], line 1
# ...

# %%
# nse.price_volume_data(symbol='SBIN', from_date='01-01-2024', period='1M')
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\nselib\capital_market\capital_market_data.py:96, in get_price_volume_data(symbol, from_date, to_date)
#      95 with open('file.csv', 'w') as f:
# ---> 96     f.write(data_text)
#      97 f.close()
#
# File c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\encodings\cp1252.py:19, in IncrementalEncoder.encode(self, input, final)
#      18 def encode(self, input, final=False):
# ---> 19     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
#
# UnicodeEncodeError: 'charmap' codec can't encode character '\x82' in position 178: character maps to <undefined>
#
# During handling of the above exception, another exception occurred:
#
# NSEdataNotFound                           Traceback (most recent call last)
# Cell In[44], line 1
# ...

# %%
nse.price_volume_and_deliverable_position_data(symbol='SBIN', from_date='01-01-2024', period='1M')
# Out:
# c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\nselib\capital_market\capital_market_data.py:38: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0    SBIN     EQ  07-Feb-2024     650.25     655.05     677.95    655.00
# 1    SBIN     EQ  08-Feb-2024     675.25     680.40     718.90    678.50
# 2    SBIN     EQ  09-Feb-2024     699.55     703.65     728.35    694.20
# 3    SBIN     EQ  12-Feb-2024     725.25     726.00     726.00    704.50
# 4    SBIN     EQ  13-Feb-2024     707.90     708.55     718.00    702.15
# ...

# %% [markdown]
# # **Index Data**

# %%
nse.index_data(index="NIFTY 50",period="1M")
# Out:
# c:\Users\aksha\AppData\Local\Programs\Python\Python311\Lib\site-packages\nselib\capital_market\capital_market_data.py:226: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)
#      TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  HIGH_INDEX_VAL  CLOSE_INDEX_VAL  \
# 0   07-02-2024   NIFTY 50        22045.05        22053.30         21930.50
# 1   08-02-2024   NIFTY 50        22009.65        22011.05         21717.95
# 2   09-02-2024   NIFTY 50        21727.00        21804.45         21782.50
# 3   12-02-2024   NIFTY 50        21800.80        21831.70         21616.05
# 4   13-02-2024   NIFTY 50        21664.30        21766.80         21743.25
# ...

# %%
nse.market_watch_all_indices()
# Out:
#                      key                                      index  \
# 0   BROAD MARKET INDICES                                   NIFTY 50
# 1   BROAD MARKET INDICES                              NIFTY NEXT 50
# 2   BROAD MARKET INDICES                                  NIFTY 100
# 3   BROAD MARKET INDICES                                  NIFTY 200
# 4   BROAD MARKET INDICES                                  NIFTY 500
# ..                   ...                                        ...
# 68  FIXED INCOME INDICES  NIFTY 10 YR BENCHMARK G-SEC (CLEAN PRICE)
# 69  FIXED INCOME INDICES                   NIFTY 4-8 YR G-SEC INDEX
# 70  FIXED INCOME INDICES                 NIFTY 11-15 YR G-SEC INDEX
# 71  FIXED INCOME INDICES          NIFTY 15 YR AND ABOVE G-SEC INDEX
# 72  FIXED INCOME INDICES                NIFTY COMPOSITE G-SEC INDEX
#
#           indexSymbol      last  variation  percentChange      open      high  \
# ...

# %% [markdown]
# # **Short Selling Data**

# %%
nse.short_selling_data(period='1M')
# Out:
#            Date      Symbol                        SecurityName  Quantity
# 0   31-Jan-2024      ZOMATO                      ZOMATO LIMITED    10,000
# 1   31-Jan-2024        SAIL            STEEL AUTHORITY OF INDIA     2,300
# 2   31-Jan-2024        SAIL            STEEL AUTHORITY OF INDIA     6,350
# 3   01-Feb-2024  METROPOLIS       METROPOLIS HEALTHCARE LIMITED     4,800
# 4   02-Feb-2024  IBULHSGFIN  INDIABULLS HOUSING FINANCE LIMITED  1,00,000
# 5   08-Feb-2024         UPL                         UPL LIMITED     7,500
# 6   08-Feb-2024  IDFCFIRSTB                IDFC FIRST BANK LIMI    97,500
# 7   12-Feb-2024  BALRAMCHIN           BALRAMPUR CHINI MILLS LTD     8,000
# 8   21-Feb-2024     SBICARD             SBI CARDS & PAY SER LTD       800
# 9   22-Feb-2024  BERGEPAINT           BERGER PAINTS (I) LIMITED    35,448
# 10  22-Feb-2024     SBICARD             SBI CARDS & PAY SER LTD     6,590
# 11  22-Feb-2024     RBLBANK                RBL BANK LIMITED        17,500
# ...
